# %%
# !pip install mysql-connector-python
# !pip install pypika --user
#obtener usuarios de twitter
import pandas as pd
import requests
from IPython.display import HTML, display
from bs4 import BeautifulSoup
from bs4 import Comment
import json
import html
import re
import urllib.parse

import locale
import time
from datetime import datetime
from threading import Thread
from tqdm import tqdm
import mysql.connector
import pypika
from pypika import Table, Query, MySQLQuery

# %% [markdown]
# ## Instrucciones para que ande la notebook:
# - Tener una db local de mysql corriendo
# - Tener el archivo db_conn.json en la ruta ../config/

# %%
with open('../config/db_conn.json', 'r') as db_config_file:
    db_config=json.loads(db_config_file.read())
print('Conectando a', db_config['host'])

mydb = mysql.connector.connect(
    host=db_config['host'],
    user=db_config['user'],
    password=db_config['password'],
    database=db_config['database'],
    charset=db_config['charset'],
    port=db_config['port']
)
print('Conectado :)')
# Out:
# Conectando a 127.0.0.1
# Conectado :)

# %% [markdown]
# ## Funciones básicas de scrapeo

# %%
def get_profile_timeline_header(username, guest_token, bearer_token):
    return {
        "accept": "*/*",
        "accept-encoding": "gzip, deflate",
        "accept-language": "es-US,es;q=0.9,es-419;q=0.8,en;q=0.7,gl;q=0.6,fr;q=0.5",
        "authorization": "Bearer "+bearer_token,
        "origin": "https://twitter.com",
        "referer": "https://twitter.com/"+username,
        "sec-fetch-dest": "empty",
        "sec-fetch-mode": "cors",
        "sec-fetch-site": "same-site",
        "user-agent": "Mozilla/5.0 (Linux; Android 6.0.1; Moto G (4)) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Mobile Safari/537.36",
        "x-guest-token": guest_token,
        "x-twitter-active-user": "yes",
        "x-twitter-client-language": "es"
    }
def get_profile_timeline_params(user_id, count=1000):
    return {
        "include_profile_interstitial_type": 1,
        "include_blocking": 1,
        "include_blocked_by": 1,
        "include_followed_by": 1,
        "include_want_retweets": 1,
        "include_mute_edge": 1,
        "include_can_dm": 1,
        "include_can_media_tag": 1,
        "skip_status": 1,
        "cards_platform": "Web-12",
        "include_cards": 1,
        "include_ext_alt_text": 'true',
        "include_reply_count": 1,
        "tweet_mode": "extended",
        "include_entities": 'true',
        "include_user_entities": 'true',
        "include_ext_media_color": 'true',
        "include_ext_media_availability": 'true',
        "send_error_codes": 'true',
        "simple_quoted_tweet": 'true',
        "include_tweet_replies": 'true', #respuestas
        "userId": user_id,
        "count": count,
        "ext": "mediaStats,highlightedLabel",
        "include_quote_count": 'true'
    }
def get_profile_timeline_url(user_id, count=1000):
    request_params = get_profile_timeline_params(user_id, count)
    return 'https://api.twitter.com/2/timeline/profile/'+str(user_id)+'.json?'+urllib.parse.urlencode(request_params)

# %%
def extract_tweet_entities(tweet):
    entities = {
        'user_mentions': False,
        'user_mentions_l':0,
        'hashtags': False,
        'hashtags_l': 0,
        'urls': False,
        'urls_l': 0,
        'media': False,
        'media_l': 0,
    }
    if(not 'entities' in tweet):
        return entities
    en = tweet['entities']
    if('user_mentions' in en):
        entities['user_mentions'] = [
            {
                'tweet_owner': tweet['user_id_str'], 'tweet_id': tweet['id_str'],
                'user_id': m['id_str']
            }
        for m in en['user_mentions']]
        entities['user_mentions_l'] = len(entities['user_mentions'])
    if('hashtags' in en):
        entities['hashtags'] = [
            {
                'tweet_owner': tweet['user_id_str'], 'tweet_id': tweet['id_str'],
                'hashtag': m['text']
            }
        for m in en['hashtags']]
        entities['hashtags_l'] = len(entities['hashtags'])
    if('urls' in en):
        entities['urls'] = [
            {
                'tweet_owner': tweet['user_id_str'], 'tweet_id': tweet['id_str'],
                'url': m['expanded_url']
            }
        for m in en['urls']]
        entities['urls_l'] = len(entities['urls'])
        
    extended = False
    if('extended_entities' in tweet):
        if('media' in tweet['extended_entities']):
            extended = True
            entities['media'] = [
                {
                    'tweet_owner': tweet['user_id_str'], 'tweet_id': tweet['id_str'],
                    'media_id':m['id_str'], 'url':m['media_url_https'], 'type':m['type']
                }
            for m in tweet['extended_entities']['media']]
            entities['media_l'] = len(entities['media'])
            
    if('media' in en and not extended):
        entities['media'] = [
            {
                'tweet_owner': tweet['user_id_str'], 'tweet_id': tweet['id_str'],
                'media_id':m['id_str'], 'url':m['media_url_https'], 'type':m['type']
            }
        for m in en['media']]
        entities['media_l'] = len(entities['media'])
        
    return entities

def extract_tweet_data(tweet):
    try:
        if(len(re.findall(r'^(RT )', tweet['full_text']))):
            return False
        is_quote = tweet['is_quote_status'] if ('is_quote_status' in tweet) and ('quoted_status_id_str' in tweet) else False
        is_reply = 'in_reply_to_status_id_str' in tweet
        source = re.findall(r'>(.+)</a>$', tweet['source'])
        source = source[0] if len(source)==1 else ''
        entities = extract_tweet_entities(tweet)
        return {
            'tweet': {
                'tweet_id': tweet['id_str'],
                'conversation_id': tweet['conversation_id_str'],
                'user_id': tweet['user_id_str'],
                'created_at': datetime.strptime(tweet['created_at'], '%a %b %d %H:%M:%S %z %Y').strftime('%Y-%m-%d %H:%M:%S'),
                'lang': tweet['lang'],
                'retweet_count': tweet['retweet_count'],
                'favorite_count': tweet['favorite_count'],
                'reply_count': tweet['reply_count'],
                'quote_count': tweet['quote_count'],
                'is_reply': is_reply,
                'replied_id': tweet['in_reply_to_status_id_str'] if is_reply else None,
                'replied_user_id': tweet['in_reply_to_user_id_str'] if is_reply else None,
                'replied_original': tweet['in_reply_to_status_id_str']==tweet['conversation_id_str'] if is_reply else None,
                'is_quote': is_quote,
                'quoted_id': None if not is_quote else tweet['quoted_status_id_str'],
                'full_text': tweet['full_text'],
                'source': source,
                'user_mentions_count': entities['user_mentions_l'],
                'hashtags_count': entities['hashtags_l'],
                'urls_count': entities['urls_l'],
                'media_count': entities['media_l'],
            },
            'entities': {
                'tweet_id':tweet['id_str'],
                'user_mentions': entities['user_mentions'],
                'hashtags': entities['hashtags'],
                'urls': entities['urls'],
                'media': entities['media'],
            }
        }
    except:
        return False

def get_tweets_data(tweets):
    processed = [extract_tweet_data(tweet[1]) for tweet in tweets]
    processed = [tweet for tweet in processed if tweet != False]
    processed_tweets = [tweet['tweet'] for tweet in processed]
    processed_entities = [tweet['entities'] for tweet in processed]

    get_entity = lambda processed_entities, name: [
        tweet[name] for tweet in processed_entities if tweet[name] != False
    ]

    entities_user_mentions = get_entity(processed_entities, 'user_mentions')
    entities_hashtags = get_entity(processed_entities, 'hashtags')
    entities_urls = get_entity(processed_entities, 'urls')
    entities_media = get_entity(processed_entities, 'media')

    
    return processed_tweets, entities_user_mentions, entities_hashtags, entities_urls, entities_media

# %%
def _get_user_prop(prop, user):
    if(prop in user):
        return user[prop]
    return None
def _get_user_image(user):
    if('profile_image_url_https' in user):
        return [
            user['profile_image_url_https'].replace('_normal.', '_400x400.'),
            user['profile_image_url_https']
        ]
    return [None, None]

def extract_user_data(user):
    geo_enabled = 'geo_enabled' in user
    verified = 'verified' in user
    pinned_tweet = user['pinned_tweet_ids_str'][0] if len(user['pinned_tweet_ids_str']) else None
    user_image = _get_user_image(user)
    return {
        'user_id': user['id_str'],
        'user_name': user['screen_name'],
        'name': user['name'],
        'description': user['description'],
        'url': _get_user_prop('url', user),
        'created_at': datetime.strptime(user['created_at'], '%a %b %d %H:%M:%S %z %Y').strftime('%Y-%m-%d %H:%M:%S'),
        'geo_enabled': _get_user_prop('geo_enabled', user),
        'verified': _get_user_prop('verified', user),
        'profile_image_url': user_image[1],
        'profile_image_url_large': user_image[0],
        'followers_count': user['followers_count'],
        'friends_count': user['friends_count'],
        'listed_count': user['listed_count'],
        'favourites_count': user['favourites_count'],
        'statuses_count': user['statuses_count'],
        'media_count': user['media_count'],
        'pinned_tweet': pinned_tweet,
        'tweets_scraped': None,
    }

def get_users_data(users):
    return [extract_user_data(user[1]) for user in users]

# %%
def get_bearer_token():
    _rq_header = {'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:56.0) Gecko/20100101 Firefox/56.0'}
    response = requests.get('https://abs.twimg.com/responsive-web/web/main.92eeeb04.js', headers=_rq_header)
    token = re.findall(r's="(AAAAAA[^"]+)"', response.text)[0]
    return token
def get_guest_token():
    _rq_header = {
        'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:56.0) Gecko/20100101 Firefox/56.0',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8',
        'Host': 'mobile.twitter.com',
        'Accept-Encoding': 'gzip, deflate',
        'DNT': '1',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        "origin": "https://mobile.twitter.com",
        "referer": "https://mobile.twitter.com",
    }
    s = requests.Session()
    response = s.get('https://mobile.twitter.com/', headers=_rq_header)
    token = s.cookies.get_dict()['gt']
#     token = re.findall(r'decodeURIComponent\("gt=([^;]+);', response.text)[0]
    return token
def get_id_from_username(username, guest_token, bearer_token):
    request_params = {
        "variables": json.dumps({
            "screen_name": username,
            "withHighlightedLabel": True
        })
    }
    req_url = 'https://api.twitter.com/graphql/-xfUfZsnR_zqjFd-IfrN5A/UserByScreenName?'+urllib.parse.urlencode(request_params)
    _rq_header = {
        "accept": "*/*",
        "accept-encoding": "gzip, deflate",
        "accept-language": "es-US,es;q=0.9,es-419;q=0.8,en;q=0.7,gl;q=0.6,fr;q=0.5",
        'User-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:56.0) Gecko/20100101 Firefox/56.0',
        'referer': 'https://mobile.twitter.com/'+username,
        'origin': 'https://mobile.twitter.com',
        'authorization': 'Bearer '+bearer_token,
        'x-guest-token': guest_token,
        "sec-fetch-dest": "empty", "sec-fetch-mode": "cors", "sec-fetch-site": "same-site", "x-twitter-active-user": "yes", "x-twitter-client-language": "es"
    }
    response = requests.get(req_url, headers=_rq_header)
    data = json.loads(response.text)
    user_id = data['data']['user']['rest_id']
    return user_id

# %%
def test_lang(tweets, desired_lang='es'):
    tweets = [ 1 if t['lang']==desired_lang else 0 for t in tweets ]
    return sum(tweets) / len(tweets) > .5

def search_user_in_list(users, user_id):
    users = [ user for user in users if user['user_id'] == user_id ]
    if(len(users)!=1):
        return False
    return users[0]

def get_profile_timeline_data(username, guest_token, bearer_token, count=10, user_id=False):
    
    if(user_id == False):
        user_id = get_id_from_username(username, guest_token, bearer_token)
    
    headers = get_profile_timeline_header(username, guest_token, bearer_token)
    url = get_profile_timeline_url(user_id, count)
    page_response = requests.get(url, headers=headers)
    
    if(page_response.status_code != 200):
        print(page_response.text)
        return False
    
    response_json = json.loads(page_response.text)
    tweets = response_json['globalObjects']['tweets']
    users = response_json['globalObjects']['users']
    
    processed_users = get_users_data(list(users.items()))
    
    processed_tweets, entities_user_mentions, entities_hashtags, entities_urls, entities_media = get_tweets_data(list(tweets.items()))
    
    lang_es = test_lang(processed_tweets)
    user_data = search_user_in_list(processed_users, user_id)
    
    return  {
        'scraped_user': username,
        'scraped_user_id': user_id,
        'scraped_user_data': user_data,
        'lang_es': lang_es,
        'users': processed_users,
        'tweets': processed_tweets,
        'entities_user_mentions': entities_user_mentions,
        'entities_hashtags': entities_hashtags,
        'entities_urls': entities_urls,
        'entities_media': entities_media
    }

# %% [markdown]
# ## Funciones de db

# %%
def get_cnxn():
    cnxn = mysql.connector.connect(
        host=db_config['host'],
        user=db_config['user'],
        password=db_config['password'],
        database=db_config['database'],
        charset=db_config['charset'],
        port=db_config['port']
    )
    return cnxn

# %%
def get_users_by_id(ids, retry=True):
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    sql = """
        SELECT * FROM users where user_id IN (?)
    """
    cursor.execute(sql, ', '.join(ids))
    rows = cursor.fetchall()
    return rows

def get_db_users(users):
    users = [ tuple(user.values()) for user in users ]
    t = Table('users', 'twitter')
    c = ('user_id', 'user_name', 'name', 'description', 'url', 'created_at', 'geo_enabled', 'verified', 'profile_image_url', 'profile_image_url_large', 'followers_count', 'friends_count', 'listed_count', 'favourites_count', 'statuses_count', 'media_count', 'pinned_tweet', 'tweets_scraped')
    q = MySQLQuery.into(t).columns(c).insert( *users )
    return 'INSERT IGNORE'+str(q)[6:]

def update_scraped_user(user_id):
    cnxn = get_cnxn()
    users_table = Table('users', 'twitter')
    sql = MySQLQuery.update(users_table)\
    .set(users_table.tweets_scraped, 1)\
    .set(users_table.tweets_scraped_at, datetime.now().strftime('%Y-%m-%d %H:%M:%S'))\
    .where(users_table.user_id == user_id)
    cursor = cnxn.cursor()
    cursor.execute(str(sql))
    cnxn.commit()
    return True

def insert_db_users(users, user_id=False):
    cnxn = get_cnxn()
    sql = get_db_users(users)
    cursor = cnxn.cursor()
    cursor.execute(sql)
    cnxn.commit()
    if(user_id):
        update_scraped_user(user_id)
    return True

def update_ignore_user(user_id):
    """Marco un usuario para no scrappearlo por algun motivo (ej esta en otro idioma)"""
    cnxn = get_cnxn()
    users_table = Table('users', 'twitter')
    sql = MySQLQuery.update(users_table).set(users_table.ignore, 1).where(users_table.user_id == user_id)
    cursor = cnxn.cursor()
    cursor.execute(str(sql))
    cnxn.commit()
    
def insert_ignore_user(user):
    """Inserto y marco un usuario para no scrappearlo por algun motivo (ej esta en otro idioma)"""
    cnxn = get_cnxn()
    sql = get_db_users([user])
    cursor = cnxn.cursor()
    cursor.execute(str(sql))
    cnxn.commit()
    update_ignore_user(user['user_id'])
    return True
    
def get_sql_insert_tweets(tweets):
    columns = ('tweet_id', 'conversation_id', 'user_id', 'created_at', 'lang', 'retweet_count', 'favorite_count', 'reply_count', 'quote_count', 'is_reply', 'replied_id', 'replied_user_id', 'replied_original', 'is_quote', 'quoted_id', 'full_text', 'source', 'user_mentions_count', 'hashtags_count', 'urls_count', 'media_count')
    if(list(tweets[0].keys()) != list(columns)):
        raise Exception('Tweets and db columns are not equal.')
    tweets = [ tuple(tweet.values()) for tweet in tweets ]
    table = Table('tweets', 'twitter')
    sql = MySQLQuery.into(table).columns(columns).insert( *tweets )
    return 'INSERT IGNORE'+str(sql)[6:]

def insert_db_tweets(tweets):
    """Inserto un array de tweets en la db"""
    cnxn = get_cnxn()
    sql = get_sql_insert_tweets(tweets)
    cursor = cnxn.cursor()
    cursor.execute(sql)
    cnxn.commit()
    return True

def insert_db_rt(user_id, tweets):
    """Inserta retweets hechos por un user_id"""
    retweets = [[tweet['user_id'], tweet['tweet_id'], user_id] for tweet in tweets if user_id != tweet['user_id']]
    columns = ('tweet_owner', 'tweet_id', 'user_id')
    table = Table('retweets', 'twitter')
    sql = MySQLQuery.into(table).columns(columns).insert( *retweets )
    sql = 'INSERT IGNORE'+str(sql)[6:]
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    cursor.execute(str(sql))
    cnxn.commit()
    return True

def insert_db_hashtags(hashtags):
    """Inserta retweets hechos por un user_id"""
    hashtags = [tuple(hashtag.values()) for hashtags_t in hashtags for hashtag in hashtags_t]
    columns = ('tweet_owner', 'tweet_id', 'hashtag')
    table = Table('hashtags', 'twitter')
    sql = MySQLQuery.into(table).columns(columns).insert( *hashtags )
    sql = 'INSERT IGNORE'+str(sql)[6:]
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    cursor.execute(sql)
    cnxn.commit()
    return True

def insert_db_media(medias):
    """Inserta retweets hechos por un user_id"""
    items = [tuple(i.values()) for tweet in medias for i in tweet]
    columns = ('tweet_owner', 'tweet_id', 'media_id', 'url', 'type')
    table = Table('media', 'twitter')
    sql = MySQLQuery.into(table).columns(columns).insert( *items )
    sql = 'INSERT IGNORE'+str(sql)[6:]
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    cursor.execute(sql)
    cnxn.commit()
    return True

def insert_db_mentions(mentions):
    """Inserta retweets hechos por un user_id"""
    items = [tuple(i.values()) for tweet in mentions for i in tweet]
    columns = ('tweet_owner', 'tweet_id', 'user_id')
    table = Table('mentions', 'twitter')
    sql = MySQLQuery.into(table).columns(columns).insert( *items )
    sql = 'INSERT IGNORE'+str(sql)[6:]
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    cursor.execute(sql)
    cnxn.commit()
    return True

def insert_db_urls(urls):
    """Inserta retweets hechos por un user_id"""
    items = [tuple(i.values()) for tweet in urls for i in tweet]
    columns = ('tweet_owner', 'tweet_id', 'url')
    table = Table('urls', 'twitter')
    sql = MySQLQuery.into(table).columns(columns).insert( *items )
    sql = 'INSERT IGNORE'+str(sql)[6:]
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    cursor.execute(sql)
    cnxn.commit()
    return True

# %% [markdown]
# ## Ejemplos de db
# Insertar un grupo de usuarios en la db:
# ```python
# insert_db_users(response['users'])
# insert_db_users(response['users'], response['scraped_user_id']) #actualiza el usuario scrappeado
# ```
# Marcar un usuario que no quiero scrappear:
# ```python
# user = response['scraped_user_data'] #json de usuario
# insert_ignore_user(user)
# ```
# Guardar tweets:
# ```python
# insert_db_tweets(response['tweets'])
# ```
# Guardar retweets:
# ```python
# user_id = '1234'
# insert_db_rt(user_id, response['tweets'])
# ```
# Obtener usuarios ya scrappeados:
# ```python
# get_users_by_id(['134', '4568'])
# ```
# Insertar media:
# ```python
# insert_db_hashtags(response['entities_hashtags'])
# insert_db_media(response['entities_media'])
# insert_db_mentions(response['entities_user_mentions'])
# insert_db_urls(response['entities_urls'])
# ```
#
# ## Ejemplo para obtener usuario:
# ```python
# username = 'ejemplo_sin_arroba'
# user_id = '149991703'
# count = 500
# bearer_token = get_bearer_token()
# guest_token = get_guest_token()
#
# get_id_from_username(
#     username,
#     guest_token,
#     bearer_token,
#     count,
#     user_id #(opcional)
# )
# ```
#
# #### Respuesta:
# La respuesta sera un diccionario con los siguientes atributos:
# ```python
# scraped_user, #username scrapeado
# scraped_user_id, #user_id scrapeado
# scraped_user_data, #data del usuario scrappeado
# lang_es, #la mayoría de los tweets están en español
# users, #array el usuario + todos los usuarios con los que interactuó
# tweets, #array todos los tweets + rt (pueden no ser originales del usuario que solicite)
# entities_user_mentions, #array las menciones
# entities_hashtags, #array los hashtags utilizados
# entities_urls, #array urls utilizadas
# entities_media #imagenes/videos
# ```

# %%
user_id = '149991703'
bearer_token = get_bearer_token()
guest_token = get_guest_token()

response = get_profile_timeline_data(
    'alferdez',
    guest_token,
    bearer_token,
    500,
    user_id
)

# %%
response['lang_es']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c6464e94d260> in <module>
# ----> 1 response['lang_es']
#
# NameError: name 'response' is not defined

# %% [markdown]
# ### Ahora si a scrapear

# %%
bearer_token = get_bearer_token()
guest_token = get_guest_token()
count_scrapped = 0

# %%
def save_user_data(response):
    insert_db_users(response['users'], response['scraped_user_id'])
    insert_db_tweets(response['tweets'])
    insert_db_rt(response['scraped_user_id'], response['tweets'])
    insert_db_hashtags(response['entities_hashtags'])
    insert_db_media(response['entities_media'])
    insert_db_mentions(response['entities_user_mentions'])
    insert_db_urls(response['entities_urls'])
    return True

def scrap_save_user(user_name, user_id=False, verbose=False):
    global count_scrapped
    global bearer_token
    global guest_token
    if(verbose):
        print('------Init:', user_name)
    if((count_scrapped % 10) == 0):
        if(verbose):
            print('RESET_TOKENS')
        count_scrapped = 0
        bearer_token = get_bearer_token()
        guest_token = get_guest_token()
    count_scrapped+=1
    response = get_profile_timeline_data(
        user_name,
        guest_token,
        bearer_token,
        6000,
        user_id
    )
    if(not response['lang_es']):
        #No esta en español, me evito scrappear la cuenta a futuro
        if(verbose):
            print('Not spanish', user_name)
        insert_ignore_user(response['scraped_user_data'])
        return False
    #Guardo la data
    if(verbose):
        print('Saving', user_name, '...')
    save_user_data(response)
    if(verbose):
        print('Saved', user_name)
    return response
def get_new_targets():
    sql = """
        SELECT user_id, user_name FROM users where
        `ignore`= 0 and `tweets_scraped` = 0
        order by followers_count desc
    """
    cnxn = get_cnxn()
    cursor = cnxn.cursor()
    cursor.execute(sql)
    rows = cursor.fetchall()
    return rows

# %%
user_targets = ['alferdez', 'Kicillofok', 'horaciorlarreta', 'mauriciomacri', 'CFKArgentina', 'NicolasdelCano', 'jlespert', 'JMilei']

for i in user_targets:
    scrap_save_user(i, verbose=True)
# Out:
# ------Init: alferdez
# Saving alferdez ...
# Saved alferdez
# ------Init: Kicillofok
# Saving Kicillofok ...
# Saved Kicillofok
# ------Init: horaciorlarreta
# Saving horaciorlarreta ...
# Saved horaciorlarreta
# ------Init: mauriciomacri
# Saving mauriciomacri ...
# Saved mauriciomacri
# ------Init: CFKArgentina
# Saving CFKArgentina ...
# Saved CFKArgentina
# ------Init: NicolasdelCano
# Saving NicolasdelCano ...
# Saved NicolasdelCano
# ------Init: jlespert
# Saving jlespert ...
# Saved jlespert
# ------Init: JMilei
# Saving JMilei ...
# Saved JMilei

# %%
new_targets = get_new_targets()
for i in new_targets:
    try:
        scrap_save_user(i[1], i[0] , verbose=True)
    except:
        print('####### ERROR #######', i)
# Out:
# ------Init: CNNEE
# Saving CNNEE ...
# Saved CNNEE
# ------Init: cuervotinelli
# Saving cuervotinelli ...
# Saved cuervotinelli
# ------Init: NoticiasRCN
# Saving NoticiasRCN ...
# Saved NoticiasRCN
# ------Init: lopezdoriga
# Saving lopezdoriga ...
# Saved lopezdoriga
# ------Init: JuanManSantos
# Saving JuanManSantos ...
# Saved JuanManSantos
# ------Init: todonoticias
# Saving todonoticias ...
# Saved todonoticias
# ------Init: marley_ok
# Saving marley_ok ...
# Saved marley_ok
# ------Init: manuginobili
# Saving manuginobili ...
# Saved manuginobili
# ------Init: eltreceoficial
# Saving eltreceoficial ...
# Saved eltreceoficial
# ------Init: elmundoes
# Saving elmundoes ...
# Saved elmundoes
# ------Init: rialjorge
# Saving rialjorge ...
# Saved rialjorge
# ------Init: LANACION
# Saving LANACION ...
# Saved LANACION
# ------Init: delpotrojuan
# Saving delpotrojuan ...
# Saved delpotrojuan
# ------Init: clarincom
# Saving clarincom ...
# ...

# %%
tt = [
('305073570', 'ChrisGiles_'),
('152835465', 'JuanGrabois'),
('158906112', 'IglesiasDiego'),
('327524667', 'Facundo_Moyano'),
('112822128', 'mayrasmendoza'),
('306546830', 'NicoDujovne'),
('1114590254', 'Winston_Dunhill'),
('75797367', 'dandrezner'),
('3399074854', 'Martin_M_Guzman'),
('240265305', 'anadoluagency'),
('108968018', 'LPOArg'),
('249776485', 'javierpanza'),
('19029918', 'CarlosHeller'),
('1043198260092039169', 'MiguelPichetto'),
('138146308', 'Gregoriodalbon'),
('164559805', 'EdgardoRovira'),
('221540591', 'diagonalesweb'),
('36556932', 'Gbastidas'),
('51714340', 'PRossiOficial'),
('1250577332', 'futurockOk'),
('2497269751', 'Dmartinez_uy'),
('244175447', 'wildcarpincho'),
('1561887312', 'GiacoDiego'),
('30049238', 'matiastombolini'),
('489647415', 'Lanataenel13'),
('121514648', 'CanadaFP'),
('475249310', 'skapoficial'),
('4449919888', 'ditulliojuli'),
('147379436', 'eltatoyoung'),
('254599256', 'fargosi'),
('365491116', 'CampAbortoLegal'),
('3148689514', 'sabatinigabyok'),
('35810531', 'bill_easterly'),
('172976690', 'hanalfabeto'),
('139683504', 'DeAcaEnMas951'),
('251882678', 'AldoDuqueSantos'),
('161308045', 'jusgobar'),
('3065748729', 'radioconvos899'),
('380741459', 'pau_oliveto'),
('70724306', 'NacionalAM870'),
('3351561406', 'rechimuzziok'),
('158497464', 'nbg__'),
('162873142', 'LicDanielArroyo'),
('293682722', 'HugoYasky'),
('2516650610', 'BancoCentral_AR'),
('781293', 'martinvars'),
('169622154', 'diegocabot'),
('8877352', 'eltribuno'),
('176442061', 'arilijalad'),
('160626555', 'delfinamerino'),
('2359916634', 'QuotesforGoal'),
('60291914', 'S_Schwartzmann'),
('3209001100', 'EcoFeminita'),
('15741523', 'marcos_galperin'),
('17946159', 'sergiobergman'),
('510437685', 'soylacarbonell'),
('270168698', 'DominguezJul'),
('247540617', 'trottanico'),
('159210352', 'LuisGasulla'),
('913063871681835008', 'redfishstream'),
('3220331433', 'PolemicaBar'),
('77925638', 'Tutehumor'),
('3187616987', 'Juli_Strada'),
('3328795281', 'PPTenel13'),
('1242651794666409984', 'outofcontarg'),
('1798377216', 'BuzzFeedEspanol'),
('2714771804', 'JorgeTaiana'),
('363253547', 'AntonellaMarty'),
('119175667', 'd_balmaceda'),
('1090030958', 'nachomdeo'),
('4919962521', 'inst_PATRIAar'),
('69800760', 'Lupo55'),
('19722366', 'joseluisgioja'),
('352141933', 'rvfradiopopular'),
('92284311', 'JorgeTriaca'),
('3169963433', 'OurWorldInData'),
('420592061', 'pulso_tw'),
('1483213278', 'FerEspinozaOK'),
('410318537', 'freezerohedge'),
('1223168594', 'FerBetancourt9'),
('185043343', 'c40cities'),
('182831320', 'rinconet'),
('39490506', 'syriza_gr'),
('500964169', 'BAProvincia'),
('58226479', 'cecioviedo'),
('1043220834', 'staffdenoticias'),
('149288563', 'segregustavo'),
('1469894064', 'german_garavano'),
('3239192692', 'JimYongKimWBG'),
('1078995180', 'DanannRock'),
('4747004116', 'AFIPcomunica'),
('1132308934948282368', 'FrenteDeTodos'),
('1081168493091962880', 'pablom_m'),
('3816919516', 'CronicaTV'),
('130979339', 'norabar'),
('429400896', 'vanesavallejo3'),
('937439845714186241', 'elcoheteluna'),
('202352090', 'claudiosavoia'),
('4570789301', 'SusanaMalcorra'),
('242969570', 'rominamanguel'),
('3164905360', 'PeriodistaPeron'),
('519497576', 'larroqueandres'),
('1482333253', 'InfoNodal'),
('121039771', 'hijos_capital'),
('147398340', 'fraoneto'),
('1493451997', 'NielsenEcon'),
('988577855125835776', 'actrices_arg'),
('3311286493', 'adam_tooze'),
('1219692878911430656', 'trendingpolitik'),
('85697134', 'Navegaciones'),
('113030999', 'CeSanz1'),
('86574872', 'DanteForesi'),
('161047617', 'ZamoraJulio'),
('136481021', 'nmonckeberg'),
('516786485', 'Laoncediez'),
('1035407102', 'BanTheBBC'),
('17706291', 'elcancillercom'),
('4341845367', 'juntoscambioar'),
('19668442', 'BenjaminHarvey'),
('128205366', 'claudiapineiro'),
('11816412', 'lacapitalmdq'),
('339334958', 'GerardoMorales'),
('297784596', 'AlciraArgumedo'),
('187720540', 'macabercovich'),
('821894639284355076', 'MundoEConflicto'),
('87741293', 'rlorenzetti'),
('161439194', 'PrensaMadres'),
('110029071', 'guadavazquez'),
('799250105572491264', 'dlacalle_IA'),
('801184628', 'Mision_Verdad'),
('268516473', 'lavenganzaradio'),
('301464513', 'Fte_Izquierda'),
('124010482', 'jotaalonso'),
('127996443', 'saenzricardo'),
('2792011733', 'PrefecturaNaval'),
('137568918', 'lucasllach'),
('490489840', 'ElCipayo'),
('233630752', 'CELS_Argentina'),
('227476236', 'populardiario'),
('362914330', 'Propiedades_BA'),
('28266730', 'VickyVillarruel'),
('364383398', 'PrensaPEsquivel'),
('2573916020', 'izquierdadiario'),
('41821987', 'nberpubs'),
('301492316', 'fvallejoss'),
('184635030', 'luanavolnovich'),
('337631754', 'Gus_Noriega'),
('372817493', 'Ejercito_Arg'),
('326512684', 'AlfredoZaiat'),
('312923505', 'la_campora'),
('997167912292102144', 'ChauOperetaK'),
('148316448', 'BallesterDani'),
('301970709', 'AcostashowJuan'),
('73507614', 'betovaldez'),
('1507427378', 'SacachispasOK'),
('3368395985', 'PrensaCOA'),
('131346082', 'sol651'),
('198883031', 'rodotailhade'),
('830154425452920834', 'earthalliance'),
('1357911', 'escriba'),
('222326932', 'fernandogray'),
('3081648059', 'Santiagobulat'),
('1931514481', 'LaCornisaok'),
('100599566', 'beto_cesar'),
('130866630', 'josedel_rio'),
('485325459', 'NickyMarquez1'),
('54578941', 'iProfesional'),
('2841506345', 'JSchiaretti'),
('2705597335', 'Florenciarietto'),
('4471336875', 'INDECArgentina'),
('1169664359628509184', 'laderechadiario'),
('374699026', 'agusantonetti'),
('114582574', 'UCRNacional'),
('211696619', 'TodoNegativo'),
('267960594', 'CrisAlvarezRod'),
('135371236', 'AM750'),
('244356927', 'vtolosapaz'),
('49153460', 'SilMercado'),
('24674124', 'gadyepstein'),
('15392486', 'disclosetv'),
('1197039757', 'FerRaverta'),
('1034569116', 'AgenciaElVigia'),
('146527889', 'fspotorno'),
('210627791', 'infocielo'),
('2926600120', 'Richtopia'),
('740226843589107712', 'DiputadosAR'),
('1366380860', 'BumperCrop1'),
('288334332', 'FlorHalfon'),
('160271681', 'lilianafranco20'),
('3834915802', 'Armada_Arg'),
('42586998', 'annefrankhouse'),
('149258770', 'pietragallahora'),
('57877976', 'bbimbi'),
('355002467', 'IsmaelBermudez1'),
('175422899', 'Solanopo'),
('42932403', 'JorgeGestoso'),
('1238632703794262017', 'ElPresto2Ok'),
('382129509', 'TheWilsonCenter'),
('368746304', 'gkatopodis'),
('316583387', 'LNdata'),
('212297066', '_CLACSO'),
('960855076268015616', 'LiberalesArgen1'),
('76326090', 'U24noticias'),
('54554588', 'estipozzo'),
('225145116', 'SabinaFrederic'),
('2383882980', 'FatEmperor'),
('1207713682718969856', 'MinGenerosAR'),
('177965969', 'PACOURONDO'),
('727258832121004033', 'EducacionAR'),
('10466072', 'lacha'),
('26579339', 'PIIE'),
('554075191', 'ZetaOrlando'),
('80082883', 'kalipolis'),
('83941492', 'cabrerafran'),
('173864452', 'TodosGronchos'),
('166799115', 'danyscht'),
('575465762', 'dalesmm'),
('151170333', 'Rivadavia630'),
('728012034', 'CanalCiudadBA'),
('3490873162', 'carod2015'),
('53629563', 'gustavoforgione'),
('937071079', 'paulmromer'),
('16491569', 'JimPethokoukis'),
('55665976', 'InstitutoCato'),
('2429071284', 'etupito'),
('81828783', 'marioriorda'),
('1475504383', 'SergioBerniArg'),
('4216847717', 'ojblanchard1'),
('597499972', 'pbustinduy'),
('928610401947914240', 'echarripablo1'),
('575885116', 'DiegoGolombek'),
('117802244', 'jmkarg'),
('3321577779', 'FelicindaCluney'),
('783710695716159489', 'laveritepradama'),
('42598744', 'adiospipino'),
('158536904', 'cburgueno'),
('236458875', 'EliGAlcorta'),
('882013921061863424', 'fundlibre'),
('2696557651', 'TNAutos'),
('279334127', 'AlberdianoArg'),
('596066736', 'MontenegroViki'),
('891296900145713153', 'RCSalvarezza'),
('129364049', 'p_justicialista'),
('730423200996274176', 'jorgeferraresi'),
('171110904', 'tanoproductor'),
('126377982', 'florencialcaraz'),
('1070857758', 'EODomecq'),
('1001517475618488320', 'EugeniaRolon_'),
('257432060', 'nestorpitrola'),
('3092373641', 'alfredocornejo'),
('2589783002', 'OmarGutierrezOk'),
('421667035', 'damianpachter'),
('407230629', 'Letra_P'),
('162099154', 'sbatakis'),
('713028058207358976', 'AliciaCastroAR'),
('252168075', 'spitta1969'),
('104813095', 'aviacionline'),
('20856420', 'CarlosMaslaton'),
('3321734585', 'LaBelgrana'),
('93763185', 'rodysuarez'),
('29536477', 'ziberiaI'),
('700402159687503877', 'Economia_Ar'),
('160744644', 'FlavioBuccino'),
('272231800', 'rolandoteleSUR'),
('878235842', 'fsaintout'),
('1247076385', 'AleRuaTwit'),
('789465914387337216', 'PeroniaRepublic'),
('55066860', 'TECHOarg'),
('68873341', '_LauraDiMarco'),
('1128688446904598528', 'cenitalcom'),
('335969426', 'Leonardo_Grosso'),
('566581934', 'MauricioRojasmr'),
('801300211687690241', 'PortuariosBCN'),
('42995297', 'clarineconomico'),
('50136398', 'matiaslongoni'),
('316429650', 'megustaleerarg'),
('154785800', 'maurofederico'),
('780858179018035200', 'lanacionmas'),
('416721882', 'andreshibarra'),
('23485648', 'jeffreyatucker'),
('1339207069', 'Granaderosarg'),
('2686869089', 'MarceloFigueras'),
('200638297', 'chipicastillo'),
('844136511079559168', 'IndoPac_Info'),
('331593583', 'JonHeguier'),
('1183329784107061251', 'LanatoForever'),
('331965814', 'MartinLitwak'),
('1089134161670139905', 'LoperfidoDario'),
('242461059', 'Lipovetzky'),
('60880381', 'RobinWigg'),
('150910036', 'MarceOzz'),
('287810729', 'rcas1'),
('152353397', 'axelcapriles'),
('2691657932', 'valen_reales'),
('3447672321', 'LegadoPeron'),
('336919117', 'FarandulaShow'),
('3462240803', 'bernardallorent'),
('607311329', 'PoliticaClarin'),
('61631756', 'omarperotti'),
('132896453', 'facu_pedrini'),
('293680137', 'CTAok'),
('153369787', 'FeriaArco'),
('17843439', 'edreform'),
('95806508', 'PabloWende'),
('342181575', 'mreparaguay'),
('332543511', 'anabelfsagasti'),
('2670988922', 'vivaroca2015'),
('531656025', 'Policia_ciudad'),
('36089412', 'elsolonline'),
('24946457', 'diegodelacruz'),
('151029171', 'TRIBUNAcomar'),
('742800091', 'bancoprovincia'),
('383257612', 'EdgardoDepetri'),
('838223291466809345', 'sobrelibertad'),
('935088068', 'GustavoSaenzOK'),
('343026348', 'rubalef'),
('52243385', 'juancristonomo'),
('160341518', 'cbuteler'),
('3112019957', 'GarbarzAriel'),
('130381198', 'nachogiron'),
('824372021853306889', 'SergioOPalazzo'),
('587699611', 'BuryaileRicardo'),
('948104532', 'ziyatong'),
('130601581', 'patgow'),
('4707533116', 'TereGarciaOK'),
('47350606', 'GUENGL'),
('3297218579', 'DamiRui'),
('351902927', 'musimerides'),
('130574455', 'OscarAguadCBA'),
('1952008692', 'sjwrenlewis'),
('187775086', 'marcelapgodoy'),
('342358065', 'JulioMartinezLR'),
('637074183', 'FMLaPatriada'),
('210491487', 'ArielSujarchuk'),
('332918283', 'Lozano_Claudio'),
('241261345', 'revistacitrica'),
('2325985260', 'gabmariotto'),
('143418323', 'eduardoaduhalde'),
('809170418863112203', 'CNNArgentina'),
('2795307903', 'MoniMacha'),
('178840402', 'Nardini_Leo'),
('778413176', 'RadioCutFm'),
('90185866', 'marianoemartin'),
('1447785775', 'lugo_py'),
('1598951042', 'gabiestevezok'),
('246425698', 'pgerchunoff'),
('295860511', 'BAENegocios'),
('62811369', 'elrural'),
('73199566', 'gneffa'),
('1579326655', 'CascallaresPJ'),
('815689902', 'BAeducacion'),
('31028906', 'lesliona'),
('277052622', 'hernanletcher'),
('176294870', 'ubaldofillol'),
('833907972', 'Yosoy_Laury'),
('157760780', 'sebalacunza'),
('177612041', 'MargaWirkierman'),
('56460024', 'rafapal'),
('406196908', 'mumimumi09'),
('969989435562643456', 'Coordinadora8m'),
('10823582', 'rindart'),
('126783988', 'robertinocarles'),
('262127099', 'jorgeluisaliaga'),
('74794951', 'agrositio'),
('738202584025026560', 'pipstoch'),
('4453635868', 'menduco_liberal'),
('2812839550', 'Herezeq'),
('196377029', 'maquialifraco'),
('81487853', 'ladivagante'),
('4189935160', 'TomyFer11'),
('198579422', 'PTSarg'),
('4493878043', 'InnovacionAR'),
('940010316', 'GuillermoLipera'),
('720478634', 'El_Econ'),
('846490166994894848', 'Cronicanunciada'),
('586933252', 'sergiounac'),
('21810329', 'sdonnan'),
('607590053', 'gustavovaldesok'),
('23430560', 'Globant'),
('734811270113726464', 'JFCuevasVila'),
('1065607220203802624', 'DisobeyVen'),
('464067709', 'aletweetsnews'),
('162181568', 'slospennato'),
('60743770', 'gabrielmorini'),
('336685027', 'RominaCalderaro'),
('350902827', 'Julio_Alak'),
('175914955', 'TomiOlava'),
('4804566441', 'alberto_rsaa'),
('1215628564512628736', 'KulfasM'),
('299298402', 'dmvasco'),
('193095342', 'aliciabarcena'),
('794332', 'elcarpo'),
('187354449', 'herrerayflia'),
('270960840', 'DarioEpstein'),
('2326865079', 'brujafemininja'),
('817749044642639874', 'pasaroncosas899'),
('96795710', 'lilialemoine'),
('4744905105', 'MendozaGobierno'),
('150338431', 'gustavomenendez'),
('4135901687', 'jdoedoe101101'),
('8973802', 'infobaepolitica'),
('3306815273', 'RevPermanente'),
('219744685', 'adattellis'),
('1373675124', 'AlbertoW00'),
('597068496', 'blogdelderecho'),
('1103644744121495552', 'ABENEGASLYNCH_h'),
('42470637', 'lulitru'),
('309812848', 'AbramAldo'),
('18173515', 'AperturaCom'),
('159119360', 'pascualsergio'),
('3256203501', 'JuanManzurOK'),
('356295136', 'DARIOLOPREITE'),
('76850095', 'zonarojas'),
('154595737', 'moldavskyrober'),
('3368366073', 'VilmaIbarraL'),
('1015783563227222016', 'RepublicaNow'),
('161838613', 'dardogasparre'),
('142342559', 'CarinaCapdevila'),
('400054955', 'julianyosovitch'),
('224350148', 'MundoGremial'),
('38299186', 'p0nja'),
('418899778', 'BeckerFriedman'),
('1215400703277125640', 'Bendernautaokk'),
('35839931', 'andy_tow'),
('75309219', 'fjueguen'),
('63276066', 'labrujula24'),
('703984267945254912', 'NuestrasVocesOK'),
('917683048782503937', 'michaelxpettis'),
('148201730', 'gabyspepe'),
('143789751', 'ClaudioZlotnik'),
('184892265', 'maticolombatti'),
('209310616', 'mis2centavos'),
('1563294710', 'SalvaDiStefano'),
('4893200632', 'cbritezmisiones'),
('170306302', 'CandelariaBotto'),
('2737379453', 'Clon_43'),
('729468838828490752', 'populismo_Atroz'),
('155023985', 'carlosetchepare'),
('145652408', 'gabrieliezzi'),
('324208281', 'soyladeltango'),
('607489726', 'ubasociales'),
('632091340', 'JohnHCochrane'),
('1723102656', 'LaspinaL'),
('175295959', 'HaitiInfoProj'),
('483333360', 'endemianado'),
('793252327071309824', 'MarioSeccoOK'),
('266866430', 'nataliavolosin'),
('253636753', 'Vsiley'),
('171969696', 'gavyndavies'),
('235340755', 'chequenblanco'),
('168549091', 'marianogoro'),
('170780382', 'CrisisRevista'),
('132727626', 'marianokestel'),
('263865213', 'elbosnio'),
('768418794', 'CarlosEguiaUno'),
('199340640', 'Sr_Churchill'),
('2865876677', 'PeronismoBA'),
('2661645776', 'Mex_Libertario'),
('171660002', 'PtcRecargado'),
('478871615', 'GrinbankDaniel'),
('114471274', 'multivisionfed'),
('931579478794555393', 'cnnradioarg'),
('15331347', 'RodrigoTeijeiro'),
('154731462', 'Ale_Bodart'),
('2437879081', 'sipreba'),
('238748784', 'FedericoAchaval'),
('3763467682', 'DrDanielGollan'),
('524364476', 'pacoduranona'),
('4536762869', 'TimermanHector'),
('533161931', 'SebastianMaril'),
('924187321284558848', '_Libertarios_'),
('219294069', 'sitioandinomza'),
('356460604', 'JavierdeHaedo'),
('3419251203', 'paimadhu'),
('829043697421533184', 'mmlosardo'),
('188418399', 'BASalud'),
('364497049', 'luisrosalesARG'),
('175876963', 'elparlamentario'),
('174296070', 'ignaciocopani'),
('943487910560616448', 'HPRecalde'),
('288248421', 'LT8am830'),
('259443284', 'eticayrepublica'),
('1266803934166949889', 'protest_nyc'),
('258471703', 'hhdospierre'),
('134232117', 'bordet'),
('1182627212', 'JuanZabaletaOK'),
('135629267', 'diegowainstein'),
('408416934', 'CRAprensa'),
('38021034', 'jdorosario'),
('184171256', 'feramato'),
('33575100', 'domingocavallo'),
('49502816', 'mabiuso'),
('150667895', 'noticieronueve'),
('168932686', 'paulinor76'),
('182809592', 'gustavolcordoba'),
('59655672', 'bertellof'),
('4656269735', 'pensarnacional'),
('1145686112', 'drlisadcook'),
('158116807', 'CCC_Arg'),
('203116623', 'CruzRojaArg'),
('226803756', 'MartinSchapiro_'),
('72906953', 'julitolopez'),
('297764153', 'Brandonlegg'),
('3038722858', 'VidalAragones'),
('115754120', 'heckmanequation'),
('1034205490832654336', 'UBARectorado'),
('17952468', 'canalchatarra'),
('1170225937985785856', 'agusmurray1'),
('1254058789080379392', 'DanielSabsay1'),
('155024102', 'gbazzan'),
('8973622', 'infobaeeconomia'),
('181616227', 'domingopeppo'),
('15599302', 'vaitor'),
('4880444266', 'Data24ok'),
('243715576', 'ladyprecarizada'),
('28633244', 'Costhanzo'),
('395515726', 'sigloxxiarg'),
('217427903', 'AgrofyNews'),
('149950136', 'gilmourde9'),
('65701885', 'TealdiF'),
('111955661', 'apuiggros'),
('324091353', 'RossoFer'),
('69139927', 'AldoLema_uy'),
('158505485', 'Red__Accion'),
('1235222307083292672', 'uni2argentina'),
('265541839', 'CatenaMalbec'),
('50061474', 'albertodefazio'),
('869236921461084161', 'TomasCivetta'),
('1433204424', 'sivakme'),
('220433012', 'irrompiblesorg'),
('1019310913143394306', 'BDAprograma'),
('79755577', 'EnriqueViale'),
('38719544', 'Bellealouette'),
('17756640', 'soyjuanjomendez'),
('26496204', 'TeresaBo'),
('1243534038', 'RadioLatina1011'),
('1252345320', 'Irene010394'),
('155639783', 'CECILIAMOREAU'),
('704710591936593921', 'DelMarR_V'),
('201908004', 'vwandres'),
('1074441014625124352', 'DespertarArg'),
('584479611', 'Canal9link'),
('2387764495', 'PaulaPenacca'),
('185862047', 'mhildingohlsson'),
('1377191564', 'LiliLopezForesi'),
('1202939731', 'luissecco'),
('1136469444115488772', 'BatmanTimesSq'),
('263772248', 'provincia1270'),
('202722677', 'gabrielzelpo'),
('447461196', 'MartinFresneda'),
('851307269337829376', 'ImpuestosyE'),
('412258452', 'MarianaR31'),
('255965315', 'marisafassi'),
('4858820483', 'LaNegraVerdu'),
('51753954', 'eduardotoniolli'),
('1894594160', 'VacaNarvaja'),
('575054137', 'eduardofvaldes'),
('3115013812', 'RominaDelPla'),
('242941996', 'JorArguello'),
('201530028', 'sofiacaram'),
('340941769', 'laShegua'),
('289918613', 'PereyraJulio'),
('226366039', 'Weretilneck'),
('921274771', 'WalterVuotoTDF'),
('155304314', 'valeriafgl'),
('187373447', 'FranCafiero'),
('73172922', 'juancourel'),
('59655753', 'cgmira'),
('779340061263425537', 'SaludBAP'),
('196888473', 'LaProfekOk'),
('18592469', 'diegodillen'),
('2956952505', 'Alecbascbas'),
('4503417675', 'HCDiputadosBA'),
('66998289', 'BeaDixit'),
('3434404877', 'raul_lucarini'),
('170505141', 'PalacioJuanM'),
('52772832', 'danilerer'),
('7729252', 'juanpmansilla'),
('182300848', 'cata_1910'),
('981230259533221888', 'GrupoCallao'),
('205495781', 'lauValonso'),
('516151851', 'MatiasRodrigTDF'),
('156056618', 'vickyginzberg'),
('1482000734', 'DakaLiveShow'),
('139556774', 'queruzo'),
('733105058427080704', 'OnlyInPeronia'),
('288338089', 'Socialistas90'),
('118876821', 'PeqeniaCaja'),
('357080470', 'MiriMdeb'),
('1008516938430144512', 'franpirovano'),
('3603561195', 'NotiPortal'),
('51612869', 'QHaRi'),
('163055343', 'autopolitics'),
('128264524', 'r_cooperativa'),
('727910160367226880', 'robertoaxelrod'),
('153506617', 'silvinamarq'),
('3255308279', 'jcalvo100'),
('875013170661912577', 'rodenasale'),
('94882386', 'richardbindi'),
('4190190903', 'turca123kordoba'),
('3121611607', 'ArtanaDaniel'),
('84284298', 'mariatad'),
('2584284308', 'CNVArgentina'),
('3153041086', 'HippiesConOsde'),
('288342621', 'FelipeMiguelBA'),
('135222131', 'omarplaini53'),
('4278430372', 'CalixtoLiber'),
('152384486', 'nerypersi'),
('26757305', 'RealWorldEcon'),
('151503394', 'ludistas'),
('545402534', 'DiarioPulse'),
('1205163610332422153', 'AnonymeCitoyen'),
('140935414', 'flaborda'),
('83685403', 'DHumanosBA'),
('1469851782', 'ateprensa'),
('407769868', 'BichosdeCampo'),
('900167522', 'andreslerner90'),
('278589649', 'raultimerman'),
('43748772', 'RiesgoPaisOK'),
('3065079718', 'LID_Chile'),
('964372835396337665', 'WashaFasha'),
('2792117080', 'DiPace4'),
('1246540122', 'somosradioam530'),
('870178758', 'martinkalos'),
('215835777', 'rrouvier'),
('35112975', 'epurcito'),
('211530826', 'LaEufe'),
('879024609227665408', 'CostaAugusto9'),
('760182190185582592', 'IMFSpokesperson'),
('176835285', 'NicoOrdozgoiti'),
('933719301294641157', 'hiperfalcon'),
('1212901368', 'PuebloBeto'),
('468756160', 'gustavopecoraro'),
('2695665061', 'Pablo_Torello'),
('873894241', 'HarvardCID'),
('2752951375', 'El1escribidor'),
('42848066', 'RosanaBertone'),
('1220512040462233601', 'JoRepublicanos'),
('62584305', 'VMoralesGorleri'),
('203236587', 'leandrobusatto'),
('114085514', 'robertcaruso'),
('1188512569331519488', 'ElLiberalDiario'),
('1189487223642697728', 'GWOMaths'),
('185076776', 'Carli_Bianco'),
('1184157769605271553', 'liberyprogre'),
('2330097281', 'Rainier_W0lf'),
('122134040', '___juanjo___'),
('187920918', 'fsusbielles'),
('195067716', 'alzicarelli'),
('632210837', 'radiomitremza'),
('165879382', 'CARBAP_ARG'),
('488097570', 'ArandaDario'),
('166122395', 'ClaroSencillo'),
('1353382832', 'Ag_Monteverde'),
('1103342944340332544', 'AleDiezRT'),
('170467507', 'MartinPerezTDF'),
('373589831', 'CarmenClausse'),
('950224302', 'EstelaDiaz63'),
('152782801', 'JorgeTodesca'),
('109723052', 'impulsobaires'),
('3130721691', 'NataliaDLSok'),
('1190669251', 'osvaldo_quiroga'),
('502300703', 'UtyEnElCielo'),
('466944944', 'A_Kauderer'),
('604018650', 'PTSPrensa'),
('18928865', 'dcabo'),
('163875218', 'Patriciodc'),
('322728284', 'edgardotlsur'),
('177561510', 'pableshiff'),
('11850572', 'AlbertoDescalzo'),
('287194322', 'dipwaltercorrea'),
('3507840497', 'Marcela01404806'),
('43620417', 'andreadatri'),
('1455726283', 'pueblo2114'),
('217977555', 'LEBasterra'),
('2321060192', 'Melany98_'),
('472392232', 'SLBurstein'),
('1100155829020487682', 'tipitoenojado'),
('946100342407692288', '_Libertarios_RT'),
('155740660', 'marcoscleri'),
('134221232', 'tampocolapavada'),
('2937218295', 'SergioGCasas'),
('140177593', 'PaT350_'),
('187994187', 'LucasGhi'),
('309746061', 'elchedelosgays'),
('152119632', 'SharonMarieTate'),
('1212129950574055424', 'ChileEnLibertad'),
('2936438998', 'NoticiasdeCampo'),
('1001879983139295232', 'somostelam'),
('886776530680074246', 'AlertaProvincia'),
('63855431', 'LaMiradaRG'),
('93386212', 'natamullerroth'),
('402887468', 'UNLaOficial'),
('4723808851', 'LucioMansilla7'),
('2575754352', 'DaunoTotoro'),
('2176711704', 'Infosindicales'),
('1268299521219391488', 'MiltonFriedom5'),
('37975072', 'aier'),
('947856145', 'arba'),
('1947224671', 'MariaSeoane48'),
('2432177677', 'InjuveArg'),
('150083991', 'JornadaMendoza'),
('35797151', 'MariaZaldivar'),
('4776736715', 'LudmilaDT'),
('469410602', 'ric_sastre'),
('1017495799461269510', 'elsantaevita'),
('542778574', 'LaprogreQ'),
('540168157', 'Senado_BA'),
('144954987', 'taligoldman'),
('1477568816', 'CRLitvin'),
('127053106', 'sinurrieta'),
('1133423113109221377', 'ToroCabron_'),
('14271626', 'fedetesso'),
('232437461', 'bobdavis187'),
('2972432728', 'Carlos_AD_Viola'),
('872897560993816576', 'alexbeglenok'),
('242311942', 'ferpeirano'),
('313031699', 'CharlyMiraOK'),
('981721191281983489', 'EmbFukushima'),
('2535206777', 'Marta_1517'),
('572261509', 'andymoline'),
('1216001288439242758', 'MaresCuarentona'),
('208612518', 'GZamoraSDE'),
('259948811', 'CPMemoria'),
('153907479', 'EpiscopadoArg'),
('163549945', 'santis_looking'),
('1076215217359597568', 'MileiPresi2023'),
('1040587302353948672', 'hipotecadosuva'),
('723700260451823617', 'GrupoCurasOPP'),
('2437481640', 'RedRuralOficial'),
('893319772707991552', 'ApoderadosOrg'),
('2474417858', 'PJZurro'),
('173719898', 'Republicaecon'),
('130641077', 'ibanezsoy'),
('1231841233', 'BritosGuillermo'),
('4389021268', 'PlanBelgrano'),
('1267622877215555589', 'laderechadiari2'),
('218662676', 'lucholibertario'),
('365032400', 'javiera888'),
('4787301515', 'UCiudadana_CABA'),
('1110689323442155520', 'NosJovenesOk'),
('141635114', 'ViaBsAs'),
('1256923537', 'Metafora710'),
('184748557', 'DamianFresolone'),
('33786448', 'elvisocc'),
('143989797', 'VitoMundial'),
('2546477611', 'juanif17'),
('319291470', 'RadioAndinaMza'),
('452508128', 'ZonaNorteDiario'),
('924064215060623360', 'rockatagliatha'),
('44223209', 'rompe_teclas'),
('1189409376', 'SebastiangdlCh'),
('729118441', 'MRevUniversity'),
('1189352696161144832', 'chilepazunidad'),
('855538460354002944', 'desde_1965'),
('204502692', 'toxenv'),
('324721559', 'fotermin'),
('440967655', 'Elyobservaa16'),
('612532996', 'MauriElbueno'),
('56855688', 'polisabates'),
('4830698416', 'diariok_'),
('3029126512', 'EsquerdaDiario'),
('771366016312041472', 'josepgoded'),
('987262435', 'IgnacioValle3'),
('434459325', 'AmilcarCollante'),
('1201480908898996224', 'CapitanBetoFer'),
('209833543', 'BorisSGomezU'),
('292401193', 'DIEGOPFERNANDEZ'),
('400431833', 'SalameEsAmor'),
('19818348', 'JulianWTO_UN'),
('67210156', 'RadioJud'),
('38239319', 'goykaramelo'),
('199112737', 'hectordaer'),
('170877554', 'GonzaQuilodran'),
('159851000', 'roditoherrera'),
('931556564393168896', 'AgustinLajeQuot'),
('1239752197', 'econromesh'),
('1705190376', 'celestemacdou'),
('146547065', 'scorohernan'),
('2384043481', 'KarenRegreso'),
('1519618068', 'SassoGerman'),
('190309980', 'videmasi'),
('45629563', 'KORTAZAR'),
('472996218', 'camicrescimbeni'),
('202258498', 'OctavioCrivaro'),
('3306969352', 'iDiarioES'),
('1213665991655186432', 'ChileHayekiano'),
('342831613', 'RealDerechaCL'),
('4166871869', 'andiscapacidad'),
('53326942', 'simonjkennedy'),
('275578872', 'Gabiziblat'),
('957037590938636294', 'PabloMIturrieta'),
('266173047', 'juaniustarroz'),
('1067636449288179712', 'maximilianoreyz'),
('32438133', 'riosmauricio'),
('1272497082', 'ExpedientePol'),
('1031991161148321792', 'HoracioRubio97'),
('164059373', 'jmgaynor'),
('519933349', 'AnaLibertadMx'),
('1056525959334187008', 'SvampaM'),
('714464094586343428', 'javieroandrade'),
('16320746', 'robivillarruel'),
('445550772', 'GustavoHArrieta'),
('1022872885', 'Canal7SiPreBA'),
('43918734', 'Pepe1807'),
('601396883', 'elangelGmendo'),
('315999581', 'PanyRosas_Arg'),
('151186838', 'Capo_total'),
('181238946', 'roinfame'),
('971008145190539264', 'petrel_fabrica'),
('122802136', 'otrarodriguez'),
('2321872682', 'OMonimar'),
('201186038', 'econojournal'),
('857007624', 'mau_alvarezz'),
('1202300210837413888', 'JulioVitobello'),
('846418757081858048', 'SeguridadProv'),
('4823871099', 'SenadoFDT_BA'),
('69668594', 'LupeTagliaferri'),
('397895514', 'EsLibertadOrg'),
('1638123108', 'CaffaroOsvaldoR'),
('927621977564729345', 'SpaccesiAgustin'),
('816264453515833348', 'GralSanMartinLA'),
('2834594517', 'TvUniversidad'),
('2590499827', 'vascoechaza1'),
('879033867335815170', 'GamarnikLab'),
('593781032', 'mara_ruiz_malec'),
('162591747', 'Andrea_Gentil'),
('890169140815777795', 'NYGBertie'),
('157734297', 'ptorreslaprida'),
('181196380', 'soymariaiglesia'),
('148799237', 'RevistaHamartia'),
('1585811604', 'GildoOnorato'),
('222124298', 'PabloCarroOk'),
('199657209', 'circulorojo899'),
('234452196', 'El_Estadista'),
('164824570', 'sosagustina'),
('2489202613', 'elloropolitico'),
('1083829288670019584', 'TaoualitAmar'),
('2452080386', 'ceprodh'),
('2751685973', 'davycoen1'),
('226018699', 'juanchohuss'),
('377343180', 'alerodri1976'),
('2555702399', 'barbeitonoelia'),
('703654788689502212', 'horacioalonso16'),
('42244392', 'maguirreh'),
('1390416625', 'ronchaa'),
('709087488', 'AguilaImperial3'),
('74271824', 'careperro2_0'),
('716750606334103552', 'igon_santiago'),
('1377604344', 'GiordanoGringo'),
('1113824976589807617', 'XxiJusticia'),
('150421167', 'analiaargento'),
('69769123', 'LudusPolitikos'),
('2762155400', 'IUEuropa'),
('2903903679', 'clarinrural'),
('903109310', 'VickyTesoriero'),
('838121187536482306', 'altorrijos_'),
('4698250537', 'enriquezabala68'),
('1635801402', 'ODSAUCA'),
('1101158401', 'LeandroGabin'),
('779498837236916224', 'insfran_gildo'),
('232031038', 'mardewe'),
('331563534', 'flacoalf'),
('1142228466512867330', 'CapLiberal'),
('105654627', 'carpe_diem__007'),
('726196637337550849', 'MinutoAMinutoC5'),
('244468979', 'SticcoDaniel'),
('1691697295', 'ArabelaCarreras'),
('552512376', 'delconurbano'),
('883814495436644353', 'contribuarg'),
('304493851', 'ungsoficial'),
('1332802550', 'vikingomaldo'),
('148939636', 'liberal_a_morir'),
('145454857', 'Grosembacher'),
('2956746825', 'PodemosAsturies'),
('4267043235', 'KarinaLMariani'),
('4497008602', 'cacerolapop'),
('174648665', '24conurbano'),
('279196040', 'UCEMA_edu'),
('203335512', 'analiarach'),
('52076011', 'rgabrieldelgado'),
('884164880114343937', 'AGCadenaDelSur'),
('4190068455', 'LysStern'),
('1177870493296320512', 'Guillermohisto1'),
('210021147', 'mauriciollaver'),
('181344110', 'nachoram'),
('119063977', 'tunazo'),
('1317292950', 'juanjovazquez57'),
('457252074', 'samuel_olmos'),
('50471406', 'GabrielaInglese'),
('739813049859735552', 'SoberaniaSalud'),
('1709884286', 'naty_motyl'),
('982604001387728896', 'ArielCoremberg'),
('1037815329760661504', 'LibertariosUru1'),
('3208681887', 'silviapiazzi'),
('151562546', 'SantillanJuli1'),
('1192563278611910656', 'Sejuela603'),
('1205541711830753282', 'ObrasPublicasAR'),
('1231244679355805697', 'ALFONSO94038811'),
('83916026', 'g_espinoza'),
('143572950', 'CarlaEchichure'),
('710184493081038849', 'SindicalFederal'),
('198724534', 'ezeburgo'),
('115131295', 'Viscurt'),
('3299903945', 'left_voice'),
('327442813', 'Andreswatsonok'),
('1027929785618640896', 'Diario26Oficial'),
('162229925', 'jmramospadilla'),
('1332154837', 'JuanMPerkins'),
('355733612', 'LPalmaCane'),
('604139914', 'MAD_en_Twitt'),
('293202795', 'FCamusso'),
('243281928', 'FMediterranea'),
('1332130316', 'adrianameyerok'),
('701791659575681024', 'dariomartinezpj'),
('1006357813566767107', 'JNarcy'),
('40458914', 'sdbernard'),
('873598470', 'NotinacTW'),
('1067040987938258944', 'totocaputo6hb'),
('96809418', 'Valefanteee'),
('2405566298', 'FundacionFIL'),
('987576353653493761', 'ElDespertadorAR'),
('2706389082', 'NathiGonzalezS'),
('222693301', 'VilchesLaura'),
('2712713382', 'giovannilarosa0'),
('173987383', 'Gracielmoreno'),
('4157252692', 'RKNGlobal'),
('2714638368', 'UNAJ_oficial'),
('325690637', 'adriancaneto'),
('998592673996070912', 'ThomasSowell10'),
('190207102', 'tabarefernandez'),
('1110899315143331840', 'marielfmoreno1'),
('33510614', 'Fglamas'),
('325953031', 'CEDLAS'),
('2355859168', 'TeddyKara'),
('2158974572', 'RaulGodoyPTS'),
('351643612', 'motbv'),
('1094956040280571904', 'stewie_soy_yo'),
('1260969019009576964', 'ContraPoder30'),
('72881827', 'ElCiudadanoMza'),
('149211936', 'danielortizguer'),
('1215363411351146497', 'AntonioUriz'),
('1173148730', 'FamiliaPais'),
('1005105132386897920', 'SenadoresFPVPJ'),
('1140069588', 'DraQuinterosNic'),
('827048251', 'AlemAmarildo'),
('56274009', 'MenteZuma'),
('963842796183580674', 'CampAbortoZSur'),
('25610143', 'FedeGiammaria'),
('780385443267379201', 'ComitexMilagro'),
('568862796', 'ManuelNHussein'),
('817266176', 'elperritoyyo_'),
('734899323549294592', 'itegaok'),
('246770086', 'f_castellaneta'),
('1017892945595379714', 'TrabajadorxsC5N'),
('192085719', 'Patriesoprano'),
('4291196477', 'rubilaroja'),
('940153657', 'agustindiazcba'),
('169173026', 'Ml2ferguson'),
('1242315786', 'javierlanari'),
('1547475176', 'EcharrenF'),
('3882094395', '_OKSergio'),
('884475225357811714', 'vision_liberal'),
('154260628', 'alexmilberg'),
('896663382', 'cuberosmiguel'),
('148766705', 'rbaccarin'),
('18723861', 'GuillermoLabord'),
('272486334', 'EMercatante'),
('1087788692301926401', 'PregoneroL'),
('2454202807', 'NicoTorn1'),
('855138383030616066', 'FrenteTodos_PBA'),
('910181525391626240', 'chimi_lco'),
('3903854597', 'ARZurro'),
('1070041444474331142', 'AkeaOlmos'),
('152369649', 'valdesjorgel'),
('1225250226799337472', 'ESTENDENClA'),
('188998649', 'cristiangirard'),
('1086694369829314561', 'UncertainLars'),
('65241235', 'datomisil'),
('867437718132977667', 'vamosjuntos'),
('16555392', 'nadersebastian'),
('110043455', 'JesicaRey'),
('210213416', 'ElFantasista_'),
('3722362582', 'cato_rechazo'),
('896869283229298688', 'cordobesokk'),
('727874930692505601', 'nuevospapeles'),
('344688175', 'AsambleaporelAg'),
('269388457', 'mmargots'),
('1837161499', 'AdrianLaRioja'),
('4374151227', 'GanymedeHr'),
('145367597', 'Claubonara'),
('496915214', 'NatuchaMorales'),
('318050854', 'Lautafym'),
('2858892250', 'javiergenta'),
('136206317', 'lotienetodo'),
('139295484', 'cardozocristian'),
('142516737', 'jmvaldesre'),
('515807209', 'juliosolanas'),
('2266008547', 'masterpolitica'),
('623334075', 'adrianccorbella'),
('2202987475', 'cecanval'),
('1162798110827003904', 'danielaleoni13'),
('132770331', 'RIDTelevision'),
('858659563', 'CERES_UY'),
('85646675', 'ViaPaisOk'),
('3320530896', 'UCiudadana_Mdp'),
('2264735961', 'bastonnorma47'),
('20491909', 'DarkSideMiau'),
('2906708182', 'biencuyano'),
('2544411907', 'Barry__Ale'),
('1373434214', 'claudiomartino'),
('944357220', 'Grito_delSur'),
('1116841543', 'expectativapr'),
('1312170816', 'gracielap2018'),
('737812375', 'patriciacubria'),
('1537786843', '_DamianRV'),
('179659004', 'ANDigitalOK'),
('2994789639', 'cecilianahon'),
('2714584987', 'HaciendaPBA'),
('1571647712', 'sac_diego'),
('2725677190', 'FrancesBancaria'),
('159179757', 'CesarValicenti'),
('3374198391', 'NEprovinciabsas'),
('1114261105881362432', 'WDVL4'),
('91668194', 'Jeromorlandi'),
('381646393', 'BNiljam'),
('1215668032934117378', 'JCuattromo'),
('1096381861834772480', 'militando2019'),
('2707907065', 'spagern'),
('143857410', 'pajarocantor007'),
('943492711616741381', 'Raulcarlo8'),
('3353247171', 'mrodriguezhur'),
('3380889225', 'JavierBlancoOK'),
('883720450567794689', 'unidad_ciudad'),
('118471054', 'amoreyra'),
('60239907', 'cesardogo'),
('745419896', 'ivansasovsky'),
('155891768', 'juanagallardo1'),
('750000545755238400', 'FtheaOficial'),
('891149382556536832', 'pbmaggiolo'),
('885972891493429249', 'lilygabass'),
('748328027654860804', 'MonicaD_2016'),
('429027859', 'MiguePonceDLeon'),
('473418873', 'Luis12tucu'),
('402788572', 'FAM_Argentina'),
('203147154', 'josenunezjurado'),
('1066427304379916289', 'LoladelaGuarda'),
('199777319', 'castillaeduardo'),
('926541944813244416', 'EdgardoCanu'),
('153867477', 'MaioLamas'),
('336056562', 'karamelosantoOK'),
('725362057583968257', 'diacero_C9'),
('51864127', 'GuilloPistonesi'),
('348804417', 'roxcipo'),
('14150079', 'marinamendez'),
('194421006', 'mlaurapratt'),
('180503498', 'facumlopez'),
('1538954198', 'vilcalejandro'),
('727605460115836929', 'info135web'),
('208776673', 'omarchafifelix'),
('171681656', 'JaviAlvarezOk'),
('889647740', 'barrios_ja'),
('2888307652', 'JuanChingoFT'),
('364617709', 'unioneditorial'),
('297621379', 'UIPBA'),
('298878019', 'AlejandroCavero'),
('868600515696963584', 'Produccion_PBA'),
('1044913623171301378', 'CampAbortoCABA'),
('178047082', 'ltornarolli'),
('1062780849828126723', 'hipotecadosPBA'),
('193806246', 'Maru_Gorila'),
('355674255', 'Barbara__Brito'),
('1050369238685405185', 'AldoRichOk'),
('537723964', 'rodrigocood'),
('284311261', 'kwinnyk'),
('1168303673191075841', 'LiberalPuro'),
('732219629628723200', 'Santo_Biasatti'),
('938781767397511168', 'gustavoeloy635'),
('1124665740953554946', 'ferdejuana'),
('2694303836', 'PabloAnino'),
('1201528003626459137', 'CorralonC'),
('1013835417974726657', 'OCIPEx_arg'),
('179754123', 'arcolatrella'),
('147648333', 'vifracchia'),
('983162113', 'ARGisabella'),
('1066501744253911041', 'jimeargentina'),
('844232241458941954', 'RoadShowOk'),
('2324403894', 'BaraldiSantiago'),
('766790684162400256', 'cronicaamerica'),
('2731250260', 'FriedrichHayek_'),
('250743830', 'AresPamela'),
('4558381347', 'GobiernoLaPampa'),
('2776762530', 'UNPAZ_Oficial'),
('173613906', 'CeciGomezMirada'),
('1213875179798949888', 'callateprogre'),
('42046941', 'gms_cl'),
('1653727550', 'Yorry_Warthon'),
('279771398', 'caomse1'),
('3412557838', 'ptobahiablanca'),
('199872752', 'Juanleyes'),
('2946109617', 'Andr1Alex'),
('746008093511847936', 'Invest_ARG'),
('1163465484039327745', 'liberalextremo'),
('933298422702051328', 'LibertariosAR'),
('2822275694', 'hernanralinqueo'),
('2834264529', 'museoshoa'),
('261249639', 'Deepwiise'),
('815647170', 'prensaensenada'),
('1228812123154849792', 'LehuedeJuan'),
('1244136667268743168', 'PibLibertarios'),
('1135973198841942016', 'causas_comunes'),
('58848006', 'FrutillaLiberte'),
('1214193325290319873', 'MInfraPBA'),
('2653198379', 'PecinaLucas'),
('2699097517', 'EditorialCI'),
('1177165310', 'josefinamar14'),
('205308644', 'martindezeta'),
('886796856285691904', 'AlanRiedmaier'),
('161645730', 'IOMAgba'),
('16651525', 'mnfernandez'),
('169077615', 'PabloCiarliero'),
('771357560737783808', 'PequenoAncap'),
('89161900', 'Dianacos'),
('1357962648', 'Sol_Bajar'),
('1203802275367575552', 'VillanaReport'),
('52810214', 'duroms'),
('856161510', 'bichingui'),
('1267952862304374784', 'RSanchez1776'),
('1203421904255758336', 'tdexx22'),
('1052932138692169729', 'QHoguera'),
('155917910', 'pabloj_lopez'),
('4847390206', 'MapaResistencia'),
('1248330407629725696', 'OkSucesos'),
('395921789', 'Nallyluz'),
('2380700497', 'akoz33'),
('2891055411', 'AnyG2015'),
('59056444', 'TRIBULACIONES'),
('960659826773839873', 'Dariocharaf'),
('263678174', 'barba_candado'),
('399115698', 'peguidotti'),
('3176903547', 'Laura_Varlet17'),
('430928385', 'misionesptodos'),
('297347533', 'ToroenReposo'),
('292713520', 'Ricardo_Bustos'),
('875867534', 'ArielFerAguilar'),
('4394418556', 'fernayac'),
('80078163', 'marceloarmartin'),
('939299117347606528', 'CobraVerde5'),
('208667430', 'Hassanibal'),
('159872839', 'superatones'),
('188971731', 'Finiten'),
('60850194', 'pulsares'),
('321752474', 'edzablotsky'),
('151119951', 'sergioVillone'),
('188735096', 'fedepuy'),
('118722218', 'javierpolvani'),
('580249561', 'solmalvinas'),
('174406042', 'MLauraFiochetta'),
('1416277615', 'barandista'),
('1128811525366538242', 'Abrilcba_'),
('3407368811', 'FotoSur_Agencia'),
('1112664662556983297', 'Carasa_Gadsden'),
('969069348', 'delocostas'),
('1030269187468480512', 'HayOtraHistoria'),
('334687445', 'PichiCooke'),
('192208402', 'rzarCR'),
('1113142449793363968', 'lesjovenes'),
('187933558', 'JavierGabino'),
('167930020', 'cotyalonso'),
('1237066128', 'jonyteknon'),
('915422405597724672', 'Lucho1983ok'),
('952977496475099136', 'AgNPalabras'),
('1559380507', 'Malecholakian'),
('188569166', 'anrecupero'),
('188301197', 'JuanPabloRecs'),
('24637896', 'alterglobal'),
('422364105', 'eugeamazona'),
('4432300887', 'auddio_oc'),
('70469439', 'lojomatias'),
('69185350', 'sacreole'),
('35904870', 'AndresZiegler'),
('1155492654639198208', 'CaserioCarlos'),
('2882895125', 'DianaAssuncaoED'),
('1222213856', 'SwedeninAR'),
('308654914', 'LuquiiK'),
('550418276', 'BAInternacional'),
('811078687', 'EmilioYitzhak'),
('4588868777', 'Silvia__Cuc'),
('208599891', 'jonatanbaldivie'),
('702173855666855936', 'LU14AM830'),
('2516185064', 'Sofiaviesca4'),
('3319686539', '76_javierg'),
('1228617720939282432', 'JolavRock'),
('1029476920210206720', 'BarreraGusOk'),
('2477375678', 'DiarioNCOok'),
('996104784880066560', 'AngryAlberdi'),
('420738821', 'wtorchio'),
('2750218703', 'madygraf'),
('1001459857780826112', 'econchart'),
('840922216204234752', 'CdV_Uruguay'),
('1140476449', 'JuanFViera'),
('958523287516139521', 'OscarChocobar1'),
('611174504', 'gramcondesa'),
('1191007857371754497', 'ELRuggeri'),
('241249583', 'FlaBroffoni'),
('30223461', 'FundacionBases'),
('3003592648', 'PibeTiger'),
('168807155', 'PrensaSantaFe'),
('100549257', 'maxifirtman'),
('2617572745', 'FNFargentina'),
('1238429408031105024', 'ComanSuplente'),
('144338029', '_aivirus'),
('1329557996', 'TropaKALARK2013'),
('52631253', 'gabgodoybb'),
('2657282617', 'MPTutelar'),
('870064093', 'FreeTradeBryan'),
('1180160399666241536', 'grcastello'),
('326356863', '21Davico'),
('956213578129989632', 'HoannSetrid'),
('3082928818', 'ChiliParker'),
('1175174158675861506', 'AleksaSemashko'),
('831491606909968386', 'afectadosconi'),
('3078328263', 'LilianaValsagna'),
('406606013', 'RebFiscal'),
('537254129', 'magui311'),
('2743135090', 'amargocallejero'),
('3022343431', 'GrundSebastian'),
('3742469483', 'PortalAgroArg'),
('98665129', 'MarceDelgadoMKT'),
('851559336811823107', 'geocentrista'),
('295967366', 'gustavotraverso'),
('4601569703', 'SaberMas2015'),
('65183293', 'borisbarrera'),
('811380428', 'LuanaSimioni'),
('2912948375', 'nico_mantegazza'),
('3075497493', 'LautaroJ_PTS'),
('167461727', 'agusionno'),
('175146224', 'Jesi_mc'),
('344978020', 'MiguelAFerrerA'),
('179383997', 'NickyGeraldine'),
('953113651300519936', 'jmarambi1'),
('136293101', 'CristianMoreno9'),
('2824024553', 'MrHublot53'),
('1097365106', 'pablo3a'),
('1058313994941972480', 'FLiberar'),
('868817377', 'eduardodicola'),
('1026266576176205825', 'Aenfoco'),
('306541480', 'HernanPuddu'),
('987445100149116931', 'piluli1709'),
('313437896', 'mlauramondino'),
('981796335581061121', 'Liberalota'),
('1095552145741529088', 'DemoliendoMitos'),
('3339309107', 'CArnedo89'),
('43364339', 'Fredypm'),
('79879264', 'AdrianAcosta9'),
('53318354', 'PabloKuper'),
('1701362964', 'EMenrath'),
('3904995032', 'LatamSatelital'),
('51889576', 'hrubini'),
('2241645846', 'atemecon'),
('3587112193', 'Guapaletas'),
('2403379658', 'yosoyluzdivinaa'),
('27908380', 'jggarin'),
('3361590040', 'vodklara'),
('178408171', 'tomascarretto'),
('2569400510', 'PaulaBach3'),
('32449108', 'marianogoren'),
('191251985', 'Toomicorrea'),
('197928132', 'EmaHerreraOK'),
('836705386652651520', 'elrifleylagente'),
('1525895245', 'hormazabal_PTS'),
('206459643', 'mavirginiagomez'),
('152515820', 'pabloschiaffino'),
('467938941', 'lautiwashere'),
('1069793700119748608', 'verotenaglia'),
('624175240', 'jgsp12071979'),
('188205113', 'patbozzsan'),
('1153344851532029957', 'AlsogarayOk'),
('2603660724', 'manrom53'),
('214735830', 'briangresko'),
('1189907620733366272', 'gralglandert'),
('1028080922074251264', 'tomasbestei'),
('256544473', 'MariaChaves_'),
('154490236', 'alarconmarisa'),
('251453399', 'Sanlofe'),
('1242999787852640258', 'Marcelapersiste'),
('860974349154758656', 'AConfesionDP'),
('1644225854', 'EstecheJor'),
('164456264', 'StaCaroCarolina'),
('3425872354', 'jepistimia98'),
('845996369315856384', 'DamarisGaray_'),
('2285633988', 'clubdelibertad'),
('1124085146', 'AyeMansillaBj'),
('847625923008405505', 'ElTecladoOK'),
('556927703', 'AliciaRuizz'),
('215478642', 'AgenciaDib'),
('951883385080827905', 'HarvardBSC'),
('67155482', 'JaimeRiveraD'),
('239571551', 'monica_gpz'),
('2477284284', 'letparks'),
('596057608', 'marcelochocarro'),
('218703553', 'MaurAntunez'),
('223982409', 'guadaoliverio'),
('312027987', 'DLO_Pergamino'),
('150383108', 'Guillotadas'),
('1883432797', 'CeciMancuso'),
('124493025', 'amsanchezs'),
('1053078059539140609', 'MrMaxLiberal'),
('593296966', 'Raggnarrokk'),
('175196384', 'Diegof74noK'),
('284286244', 'valrafael'),
('579691880', 'lizabeth1665'),
('833220775', 'Willy_Covernton'),
('2165876184', 'edel1992'),
('1624049390', 'tesorita_79863'),
('775791715546501120', 'OresteHugo'),
('291760080', 'CGERAnacional'),
('784124934473801734', 'Luciapezzarini'),
('1525684885', 'elsebaferreyra'),
('188902753', 'rmrojas58'),
('286874503', 'JuanchoDiazRoig'),
('26439328', 'Claudde'),
('333967593', 'Maro_L'),
('2421150516', 'jamateos85'),
('145350858', 'juanfravilches'),
('3064512166', 'JPlauto'),
('1131654508474458112', 'Perfil1019'),
('2682877753', 'LibertariosBsAs'),
('1263451845822943232', 'AugustaValky'),
('757687696189947905', 'BozzanoGervasio'),
('281352501', 'phoebebuffay_27'),
('976999909403582464', 'FranciscoBrunaF'),
('170810295', 'ernestokorovsky'),
('1245803324080824320', 'PatriotismoOK'),
('1250814384928145409', 'orchala66'),
('3145352555', 'AerogDeBarrio'),
('716745206037684224', 'RafaHambra'),
('1261495016217853953', 'MaslAdorni'),
('125692826', 'Jota_eMe666'),
('355501358', 'giordanojuli'),
('158723978', 'nicoyacoy'),
('925113848323104769', 'Ediciones_IPS'),
('1113834359738511362', 'DerechoFiscal2'),
('1238615042255474688', 'BovedaVic'),
('331095986', 'FernandoScolnik'),
('134646009', 'saturnetroc'),
('1076574159583543296', 'AsociacionMayo'),
('1388282906', 'Leo_Espartaco'),
('869557112', 'GazzottiLucas'),
('2964404717', 'yayaninaa'),
('743790673783066624', 'fabiancagliardi'),
('315300703', 'lucksebas'),
('1438894766', 'evelyndegiuda'),
('18662104', 'CostaCarola'),
('1881872347', 'elizaldehot'),
('137715875', 'marcanoserrano'),
('760456204799844352', 'guillechavesok'),
('119023743', 'polkenn'),
('1439167903', 'natcoldplay'),
('3170179288', 'JereGuastavino'),
('1123711666431066112', 'cerezo_emanuel'),
('1016438230802141185', 'PLibMisiones'),
('1245327039059673088', 'DruidBloggerOK'),
('485286467', 'Ceci_Soria_'),
('975820558003769345', 'GonzalezPrietoC'),
('1225783851299037185', 'PabloJ_LopezOK'),
('1264302947825057792', 'AdorniNahuel'),
('1280021396', 'Barometrocm'),
('1231734206876745730', 'PhantomF45'),
('3246112660', 'Lacorte_Carla'),
('174052247', 'soylurri'),
('996820612554346497', 'gordoCGT'),
('592229624', 'GuzzoniFernando'),
('199306201', 'Antikorrupto'),
('136433611', 'GarretEdwards'),
('401567871', 'die_colman'),
('151282789', 'Brynn01'),
('2225656910', 'UlisesJimenezLH'),
('406551567', 'clonazetam'),
('930282349039964160', 'MAClasistas'),
('1160957990679339009', 'frondizi_arturo'),
('281050329', 'Aires_Armonicos'),
('214856131', 'oscargonzalezrs'),
('4691081492', 'Adriveronica1'),
('175450862', 'NinoCiber'),
('406225831', 'MarceloGraniero'),
('4703863343', 'CuraAlessandro'),
('810915250363105281', 'RemyGaston1'),
('800768299453714432', 'germanMperezD'),
('88225270', 'arieljIglesias'),
('159283118', 'FcoFritzCanales'),
('323610856', 'PabloSalinas2'),
('848780033086943232', 'nsscloud'),
('21090827', 'tatanGeorge'),
('15657019', 'sagilet'),
('628907374', 'bucarey_carlos'),
('1142609427591307264', 'cacciuttoloaldo'),
('774430870732242945', 'osojudioconprep'),
('872813305722753024', 'puhjih_vr'),
('1235038357249560576', 'ElDoctorGorila'),
('51911933', 'totosantolin'),
('2394986912', 'ArchivoLeveneBA'),
('1021934812171591680', 'TanaAnticommies'),
('291463229', '89miche'),
('1210240073154940930', 'impulso_ciudad'),
('1421380500', 'natdesOK'),
('979186207', 'SinMaripositas'),
('1060260059731636224', 'juchervo'),
('604685700', 'BairesParaTodos'),
('707218414364917760', 'secgeneralpba'),
('830228152794411009', 'PR_OSC4R'),
('728215034', 'enzoo_0101'),
('972020982184595456', 'liberal_revista'),
('305341059', 'seba_uchitel'),
('282599807', 'mhgrande'),
('14203593', 'quiquemarzo'),
('538600160', 'eduzinc'),
('1000195300059963394', 'SBoniscontro'),
('1215328691846352897', 'Egoespoeblo'),
('1012884538916253697', 'JavoRodriguezL'),
('434403911', 'evaquijano'),
('37667381', 'ClaireMandarina'),
('1517114274', 'flizarrague'),
('172867139', 'martinmenem2010'),
('3305084145', 'AleArreguezPTS'),
('733425507002376192', 'Alfonsothurler'),
('394183333', 'cba71'),
('2362941223', 'arianediaztwt'),
('159305878', 'SUSYPAVON'),
('120679431', 'pabloalejan'),
('1258452248696442885', 'Argexchangebond'),
('242936762', 'JAVERNES'),
('249325883', 'Weps_UNAS'),
('1658923891', 'AlcarazCN'),
('136441372', 'eddiegigante'),
('527926781', 'juanibalasini'),
('1139678580730925057', 'Andres99189017'),
('172919719', 'a_mouzo'),
('2357535627', 'jdato1960'),
('370476515', '03O3456'),
('579535533', 'Eugenia_M2'),
('218998888', 'vittofiori'),
('1182793699702509570', 'PrimeroDatos'),
('158525768', 'Desiree___E'),
('178884799', 'robertuitero'),
('95528390', 'georg_Ok'),
('1193575844163272704', 'es_opinar'),
('705941515068166144', 'ebt1972'),
('935900889507823616', 'LuzyFuerzaCba'),
('2273712185', 'FedericoAguile5'),
('2360411144', 'Maca_Escudero'),
('500767505', 'SiPreMza'),
('51889265', 'JPVilunir'),
('4858338214', 'comunicacionADN'),
('773136425562804224', 'sutemendoza'),
('41097796', 'guillemosso'),
('190517820', 'Agulman'),
('65272064', 'nicolasrv'),
('1330124059', 'ArtachoCarlos'),
('1168887550628507652', 'memodiario'),
('2164764644', 'elchangomobili'),
('278380213', 'mamebianchi'),
('1256161900846624769', 'Acostermoo'),
('1261506735203909633', 'Adornista_'),
('146669663', 'EDLP_amoreterno'),
('417586554', 'matiasaufieri'),
('3240876459', 'CGIPopular'),
('721239428165943296', 'discipulodemarx'),
('46254646', 'Mendiccini'),
('1148386625086509056', 'OsoObeso_'),
('883805038191181826', 'VamosSabalero'),
('1092419513444904960', 'LinaresCarlosCR'),
('90943308', '_TheElemental'),
('1242459907', 'FILIAUGUSTOARG'),
('3142099504', 'marceloduclos'),
('190350834', 'tanex62'),
('541788005', 'Pachugran'),
('3021060701', 'erisliberta'),
('92620009', 'fercho_27'),
('3087782057', '_varelanicole'),
('4926440345', 'damianamado1'),
('195172340', 'mceliagianini'),
('855472092669726722', 'BLANCAHCANTERO'),
('143508236', 'fortinducto'),
('2488898172', 'SofiaAchigar'),
('1266111060840517650', 'adoorni'),
('2511862150', 'esmeespositoo'),
('967856903052300288', 'CleverlawLegal'),
('1064238069438664704', 'PuenteAereo1'),
('168880566', 'MartinCain'),
('4756228833', 'rdsalva'),
('548728052', 'danii0c0'),
('1246956476670922755', 'McTrabajadorxs'),
('391102180', 'VivianaHuerta3'),
('3243711910', 'musso_javier'),
('121660660', 'dofipaz'),
('1243595696453881858', 'pdemnacional'),
('94516912', 'NOSTATO'),
('1260312165241761792', 'PabloD87124837'),
('170318098', 'elzahir2006'),
('1187774443596255237', 'NatFri1'),
('1137154305285341185', 'madman19711'),
('1207177007978745857', 'OsoGordoStark'),
('1239328628556644352', 'LibertarioCABA'),
('765262469887655936', 'LuDelfino2'),
('2822995444', 'lukoaguilar'),
('133898264', 'georgibitz'),
('3093686607', 'Danilema_dl'),
('77057804', 'McAddress'),
('1963783039', 'RenzoEscobar3'),
('787711010', 'JakyPaz99'),
('3027057533', 'petche64'),
('1254093761812070401', 'EconomicWarBot'),
('178756655', 'MJMendezCasarie'),
('35734328', 'analiasoledadm'),
('1057368088512028673', 'SomosCiudadOk'),
('865940452754763776', '_angelamo'),
('1635912877', 'Valeriafarmac'),
('350373960', 'susy_sm_'),
('3434126452', 'joacobl75'),
('452563236', 'MatiasAndres42'),
('3003507556', 'laura_liff'),
('760868823956328448', '1nverPersona1'),
('1180551133', 'DaniAlk3'),
('1172883665744990208', 'JoRepCUYO'),
('2197114170', 'mariaequiss1984'),
('180435933', 'SirPsychoFede'),
('1253758048516128768', 'ShogunAnjin'),
('877934235394486272', 'Marcelo558515'),
('1246449973434159106', 'PeronismoIncgn1'),
('1523670770', 'MesinaArt'),
('1074040625920659456', 'HectorRTorres2'),
('3561204381', 'frangss_'),
('827532793831911425', 'rafsevv'),
('1035140902556192769', 'hanselsSoHot'),
('938054806920364033', 'JMValenEche'),
('1148249397039382529', 'ExponiendoZur2'),
('3688599269', 'Diegoxe_13'),
('186602898', 'AlanSchamber'),
('166671074', 'mgcipo'),
('968113668700467200', 'niunamenosmza1'),
('150650890', 'gastonfragueiro'),
('873443576', 'HIGAGandulfo'),
('803755488', 'MarcosGallacher'),
('1161327180632211456', 'QBSLC_ok'),
('1197673198894145542', 'nunca_progre'),
('373186248', 'RecBsAs'),
('236803460', 'frsaxo'),
('225526166', 'UnRodro'),
('776707273', 'LibRepublicano'),
('4632808239', 'GomezMarcela80'),
('146196880', 'GermanJai'),
('1069405298585206785', 'franz1889'),
('1237642998902595584', 'OliviaBenson70'),
('155614034', 'elchinoek'),
('3141240165', 'leodeza_'),
('1541524921', 'PTSZonaOeste'),
('2788027780', 'delgadomoraluz'),
('2872406691', 'Ruben_ft_Mangel'),
('346865566', 'CPuglelli'),
('290809041', 'CalderonNatalia'),
('1276206896870043648', 'BearTrumpizador'),
('256924897', 'Marina_Rita'),
('4656157667', 'AColleSintagma'),
('3023841567', 'PescatoriJulian'),
('1052290990697009154', 'alfondoizq'),
('1199708873382383618', 'somosnosoficial'),
('74200962', 'moraybruja'),
('104559566', 'RIGNACIO1975'),
('2149262890', 'acevedo_bar'),
('975424505014378496', 'tomaspiqf'),
('319668065', 'Rrodriguez0750'),
('762073616603283458', 'roxanalopezok'),
('326500453', 'JLekovic'),
('1177675543128477696', 'Velocirraptor11'),
('2608084723', 'FlorSciutti'),
('3382538823', 'NESanIsidro'),
('1158844062348337153', 'marxismoychoris'),
('138777321', 'juanpabloruizl'),
('1048592639413641216', 'CarolaPessino'),
('1242851391326031878', 'RadioNordesteOK'),
('145458464', 'lusodan'),
('407783987', 'joseluisdamico1'),
('2461755054', 'lavarelapaula'),
('844929521891622912', 'mansilladesouza'),
('522360515', 'candela31_'),
('1248633110390083586', 'Redprecarizadxs'),
('372889585', 'leandrogalvarez'),
('875033914196336641', 'LanusTodxs'),
('899999989', 'nicfalcone'),
('460520101', 'jfScarttezzini'),
('215794835', 'manumonteleone7'),
('1090429003339624448', 'JerryLuis01'),
('356582495', 'RikyMihura'),
('38773653', 'JavierRomanoOk'),
('185699051', 'facundobrillada'),
('353026688', 'Deeborav'),
('522727262', 'reginalaurasosa'),
('78366273', 'realtavira89'),
('700448600309002240', 'RKamchatka'),
('1047232053413126144', 'RadioBicentena1'),
('137745192', 'GabrielFossa'),
('65389906', 'ej_economics'),
('4318258155', 'Chubutparatodos'),
('2615713526', 'mgposada'),
('116204007', 'marcepautassi'),
('1261829008217575424', 'adornistan'),
('902204165300080643', 'UFMMadrid'),
('2684233921', 'Seba_pintor'),
('53431401', 'b_ttos'),
('341841950', 'Gui_parodi'),
('159684520', 'SaboAlejandro'),
('828278618128338945', 'asusanaarias'),
('277719775', 'periodismoIPR'),
('62595505', 'diegocesar2009'),
('1130869693252820992', 'piraguon'),
('1108177839436824577', 'TaladroLarreta'),
('1402517396', 'EvgenyNess'),
('3146137457', 'RoberAndres1982'),
('364503234', 'AugustoMontamat'),
('404280134', 'aitor_c'),
('1262782496334323719', 'PirataAdorni'),
('837462386105860102', 'mmpcurutchet'),
('1263162486431375361', 'drdaredevil2'),
('1272974295019458560', 'ElLibertarioPe'),
('764062320553234433', 'JoeHasell'),
('4041224955', 'carolina__cacau'),
('2196360584', 'ezequielturco4'),
('2850619019', 'anarcocancu'),
('1207389399979298821', 'gordocapital'),
('177261922', 'Aldana_Maria_'),
('270462658', 'Cat_AMDT4'),
('123600982', 'Quetzaluman'),
('1066794239890268160', 'loalcro'),
('245065158', 'adrians80'),
('47816570', 'ErickWvega'),
('274583630', 'luciodelorme'),
('1902550340', 'CienciaCristina'),
('308840909', 'KryztyanLo'),
('727128933108428804', 'BordesRevista'),
('249011807', 'RinaDiaz'),
('1143912203386572800', 'contalix'),
('904185620', 'FedeeZuccaro'),
('159880214', 'rociquiroga15'),
('300185222', 'notedesvuelta'),
('1219678488300572672', 'MIGobiernoPBA'),
('1079399484835201030', 'DIOSTodoLoP'),
('842818316955803648', 'Pais_Productivo'),
('166844333', 'naftero'),
('3103282798', 'Fantasio20'),
('137119017', 'fferrellimazza'),
('1888376586', 'mateojaja'),
('1259012496733753345', 'AlexLibre13'),
('1265888611255439361', 'JulitoTemples'),
('769711590', 'juanalvarez2604'),
('885602463520366592', 'UC_SanIsidro'),
('1099664951088766976', 'GonzaLib1853'),
('442415625', 'pn_acevedo'),
('1052696988855267332', 'PlMatanza'),
('3247054984', 'valenmuniz_'),
('1153513920944115712', 'diaele_ok'),
('1271065158186684416', 'TaoPaiPai545'),
('206296253', 'RoblesAndrea'),
('264135194', 'RodneyJCampos'),
('538968467', 'AnhellAlvarez'),
('633280053', 'JasseerRivas'),
('17636498', 'darioalmada'),
('636591284', 'chaplinzanon'),
('89783670', 'fepardal'),
('205040655', 'pek82'),
('760236968009752576', 'ForoNuevMayoria'),
('42638136', 'Ignalicio'),
('732202148600107009', 'mirardesombra'),
('3018944536', 'ParediJorge'),
('556504222', 'CompteJM'),
('2355705976', 'pablopasqualiok'),
('938569003710210049', 'NaturalOrden'),
('1387322082', 'ssandrarxtop'),
('3496616480', 'mrickvcl'),
('1253395300288520195', 'pablolbertario'),
('1706076235', 'Elmiguesabe'),
('741441045649559552', 'carlos_arbia'),
('1187557874626715648', 'clandestina83'),
('1266229289780776961', 'SanMadorni1'),
('2608599623', 'franciscojaaust'),
('1264751672779329539', 'AbrazoCapo_'),
('2330472704', '__niconic__'),
('177005003', 'mfiochetta'),
('1238864433507680256', 'locura22ok'),
('1287523837', 'jmcabrera1994'),
('117157964', 'ivannayelen1'),
('1187470604548661248', 'PresidenteMilei'),
('464035417', 'elpeque93'),
('1024073810608369665', 'F_Uriel95'),
('1241882147285327873', 'NavaVzla'),
('1273334793229524994', 'Tutankadorni'),
('1063195621119721472', 'colombiacrimin1'),
('604038560', 'providaok'),
('206475038', 'manresoto'),
('1126964248117166080', 'S1lvergay'),
('3312375759', 'bracesca'),
('245265892', 'fuiajapon'),
('937203054', 'AlejoLong7'),
('174890395', 'GracelandSantos'),
('1072680392', 'F5Diario'),
('1174413811874521094', 'JuampaOrlanski'),
('1522871791', 'VanDerHulk1'),
('1187146883334135814', 'natipeperinaph'),
('2374581607', 'ro_lasserre'),
('249827439', 'sigias'),
('3350824785', 'Maile_Rod'),
('172978498', 'MariaAngCantero'),
('3106689671', 'OrtegaLu_'),
('1261863218143793153', 'AdorniTurro'),
('1063035727347376128', 'ComadrejasFilm'),
('1580696912', 'AzuM_77'),
('1206371715921649664', 'marialaura2025'),
('336043544', 'Joni_DiTommaso'),
('1017267344517861376', 'MGR2174'),
('193819777', 'VerdadlaMenti'),
('277115942', 'ernestofasola'),
('16290858', 'alimackita'),
('375991143', 'emigbusquet'),
('1710762236', 'juanmanbar'),
('4696382611', 'Ariel_Reittel'),
('170810447', 'mclarasanchez17'),
('938910160260608000', 'NoFumesBruh'),
('778575227160760320', 'renatreinforma'),
('853183954467168256', 'jba1853'),
('1262163320729190400', 'ABENEGASDORNI'),
('3058623296', 'felixjaviermll'),
('546123420', 'niky_balihaut'),
('2913987275', 'TodosOlavarria'),
('1101919898', 'Miguelbarnichea'),
('2325020337', 'tgortari'),
('468861711', 'FacuMB_'),
('111345895', 'claudioahora'),
('1249490439641522177', 'DespidosLid'),
('1961847300', 'jorhmart'),
('533607741', 'CampeonRP'),
('1243808003633152000', 'SorryMexico'),
('37658262', 'Garilleti'),
('987510735990337536', 'alemontc'),
('1625932970', 'CamiGomezzz_'),
('333456821', 'punkzerboy'),
('1209604493094084608', 'CalderonRagnar'),
('1266875214', 'VoxArgentino'),
('986311758024294400', 'Hectorm62727906'),
('1262083959099396097', 'AdorniMilei'),
('985923587776315393', 'Institutoideas_'),
('1890557276', 'MarceloAmigoOK'),
('2889996891', 'gigirula'),
('3010763988', 'RCarrilloBce'),
('362027296', 'EnLosMarcos'),
('925953326776311808', 'FrancoV79'),
('1172654174166798337', 'KSchpaliancky'),
('201923100', 'Ana_montesdeoca'),
('3270259826', 'AnGutierrez_PTS'),
('448784921', 'MicheleGuetta'),
('158818796', 'RomainaPicanto'),
('186300679', 'martinferrusso'),
('2799998063', 'CiroVogel'),
('3131596415', 'chapubarralle'),
('1150575934786932736', 'BontempoHugo'),
('87496826', 'CeMoronRamirez'),
('925777921150803968', 'pilar_julias'),
('360689054', 'CarlosLibrem'),
('173250294', 'rociiovillagran'),
('938821809369223169', 'Autmalistrasse'),
('151426839', 'GastonElTrueno'),
('30056573', '_macasaucedo'),
('760157581', 'violeta_foetra'),
('255254554', 'menntapeperina'),
('279549757', 'laurabade75'),
('66181832', 'ArturoGonzalezJ'),
('1097279938850418688', 'Mati_Sanchez2'),
('729505705015844865', 'rodrigoenchaco'),
('775819264888418309', 'unionxlibertad'),
('1268967384813051904', 'SimmonsYStanley'),
('35796048', 'santiagohaspert'),
('226020835', 'Alejandrojmf_'),
('1270067962142003200', 'Lalozazueta1'),
('3000406865', 'vigiadevillegas'),
('754344951908069377', 'LouNicastro1'),
('1254758389231616000', 'BatmanArgentin5'),
('254354409', 'Franchuus95'),
('196746479', 'AntoAnd_'),
('1020852695433744384', 'vandalicoloco'),
('162541131', 'marqueviis'),
('197153864', 'BlancoFeer'),
('258135842', 'Econolyte'),
('2924634319', 'UniCiudadanaFV'),
('456916095', 'millondegracias'),
('72317439', 'absoluteurea'),
('1017454292', 'Pablo_zlom'),
('275338497', 'WidmarGrueso'),
('1042925038398316546', 'etchart_gonzalo'),
('1261406064333008900', 'LibertariosPer3'),
('400393661', 'AdamJanoj'),
('127711556', 'Geerman84'),
('215180435', 'blopaJ'),
('83489129', 'jesusmogollonm'),
('2901979364', 'Phmarce'),
('1291641846', 'CindyPrado_'),
('210657822', 'lopez_camilo'),
('81400958', 'rominadiezv'),
('196483389', 'GastonGardella'),
('148736079', 'GabiLandart'),
('286841173', 'danielvelata'),
('778779701884153856', 'fedewoodward1'),
('1256697000772489218', 'leawest2029'),
('1003377017256140800', 'lasbolasdeltoro'),
('1124719560245096448', 'MaipuAsamblea'),
('1222955440306298880', 'HoracioLiendo'),
('1242598251527880705', 'LADERECHISTA'),
('921185878600544256', 'Virpes2'),
('61545035', 'Ariel__levy'),
('724291128695087104', 'GuadaFantin'),
('322288341', 'estefernando'),
('2800835413', 'DanielMatos1917'),
('1380099152', 'patagoniaeconom'),
('1259260989570252804', 'AWorker077'),
('143197535', 'marc_noda'),
('196664730', 'FernandaAmesVCP'),
('369502403', 'MarianC0016'),
('335504235', 'ArgNacionCabeza'),
('1352927058', 'DescalzoNico'),
('149354349', 'veronixe'),
('393693505', 'santosfreaks'),
('1048668951813742593', 'Karake09'),
('1033120409582006274', '1libra1peso'),
('1216911525614628874', 'CEEAXXI'),
('2262133697', 'PanchitaLaLoca'),
('634260752', 'Rxmmstein'),
('185844915', 'FabiCapua13'),
('279120866', 'pieri95b'),
('909923699024908288', 'lapuraverdad200'),
('155069600', 'Nuniegol'),
('1112513693143781376', 'SasovskyAsoc'),
('3234007066', 'AnaGoussies'),
('864529298404896768', 'CheddarFran'),
('1640659692', 'GCodut'),
('185163136', 'hehernandez2'),
('255443054', 'BelenRocioR'),
('502477415', 'gracielafranol'),
('1111310379014066182', 'DavidEzMaidana'),
('1167103639674085381', 'EnMielcitas'),
('861644093994270722', 'Villanuevaunaj'),
('87020945', 'luchi_tito'),
('2720985215', 'Kwanzabot1'),
('94685824', 'Rayos7'),
('131232989', 'yanychaca'),
('61038887', 'ArqTapiaguirre'),
('1138986068597006337', 'AgustinPercoco'),
('1228147221776027649', 'Av_Libertad'),
('1136078245026287617', 'FerDCarp13'),
('149171308', 'luiseloi'),
('1644229711', 'SofiAilen__'),
('757390215011074048', 'alexis_806'),
('3173104032', 'gustavoomarrom1'),
('373582830', '65_Vicky_M'),
('701768054494076928', 'marce20152019'),
('180555896', 'mauricioa_12'),
('2431018538', 'danirmincey'),
('2262414752', 'natigalamba'),
('726510900', 'MGalladorni'),
('64397165', 'soyeseroberto'),
('112527033', 'eltio88ok'),
('1206359055037546498', 'ArgentaGurkha'),
('2861581263', 'RebeldePeronia'),
('178411595', 'PaaauRomero'),
('883497730051629056', 'TodosMoreno'),
('981693570', 'GeronimoCornide'),
('1127695984702763009', 'BeigelViviana'),
('889731331', 'Juan_Confaa'),
('4570969281', 'silviitapilar'),
('1108871424318603265', 'LihuenAlbornoz'),
('1183188072084770816', 'flacojujenio'),
('1257040436188917760', 'fi_ndel'),
('707550397565702145', 'mechavarra2'),
('759866434293948418', 'Alberto30215'),
('2683490412', 'luromo5'),
('144923452', 'mauroceratto'),
('1403314110', 'MaariAbdala'),
('73048135', 'SoleBoufflet'),
('892433028181635074', 'gomezosvaldo4'),
('1261223848512544768', 'corleoniceze'),
('153624433', '1Desteyodesabor'),
('99107350', 'maverotorresg'),
('1219379825942630403', '2020Voces'),
('2733708671', 'Sel_saeg'),
('832476756', 'isacerdav'),
('2802501101', 'xlourgomezx'),
('151763608', 'malucalibre'),
('4839905296', 'PyroGabi'),
('867378917958615041', 'NelsonSombraOK'),
('2734470042', 'rodrigofllugdar'),
('997876763182104577', 'LibertarioCh'),
('128644939', 'ChinitoBrown'),
('323560247', 'Lujor78'),
('1052752251331203072', 'ucederiocuarto'),
('2666249028', 'davii_ortiz'),
('1254127868289916935', 'lubat_'),
('2945364237', 'agustinaroj0'),
('452723804', 'GuidoSalaa'),
('4720988741', 'aquilesbailoy17'),
('583288727', 'bolsolb'),
('2946734335', 'play_maker10'),
('94444834', 'Valecita70'),
('59009910', 'elcapitan_nemo'),
('317182149', 'mmartinherrera'),
('2791534127', 'herrera_yosmar'),
('3211090516', 'MarianaArreguez'),
('780505021037342720', 'NicolasMarinko1'),
('193879253', 'nikovillarino'),
('75134246', 'Petetita'),
('722982364482265088', 'AliciaAledjore'),
('1174004368523370496', 'Mechonero89'),
('4187992162', 'elpolako1982'),
('1187925396', 'LaautaroJulian'),
('1661692207', 'Nahue_Ferro'),
('2660999461', 'cielnuit23'),
('208561094', 'pablominiaci'),
('1271134855590555648', 'Ronaldorninho'),
('180406827', 'Anibalratti'),
('2770220920', 'FedeIst'),
('880151392731705346', 'MicaBlancoMinol'),
('134973322', 'Magusfernandez'),
('793949235796443136', 'GastonBJ'),
('1039644050511613952', 'ta_myri'),
('998520332423180289', 'CrotalusLiberal'),
('2332746498', 'tinchomeza_'),
('1367604961', 'AbrilBovina_12'),
('3125684218', 'rmbonso'),
('3222827459', 'julydavicco'),
('242326156', 'daann7'),
('329357373', 'kidorytrp'),
('633082783', 'GomzGaston'),
('169513911', 'Danielalbertop'),
('1263635591691993089', 'fita1021'),
('733805951560605697', 'haolivera'),
('1174732049300774914', 'ArlexonR'),
('422787054', 'lautycespedes'),
('4560853817', 'SolCheliz'),
('1084965953547456512', 'AlidaFerreyraU'),
('3904292398', 'emanuel_ema_'),
('870595039', 'medinalaurab'),
('1092888081743708160', 'Marcial21834544'),
('1254159932401778688', 'CampusLid'),
('1095051389225631744', 'segg1337'),
('165629052', 'Julietazoom'),
('264254557', 'manuNoV23'),
('79353324', 'CRISTIAN_HOK'),
('1050239130754580481', 'NicxMvnsi'),
('1046469750497456129', 'juan_my89'),
('798705925578231808', 'QNoMeCalloNada'),
('916843347372920832', 'BasesArg'),
('1082016328997851136', 'moment_waldo'),
('1160309753815478272', 'CabezaChoclo'),
('990693870550822913', 'CidPaolaCecilia'),
('2439248838', 'JonyPresti'),
('2270921329', '__danvergara__'),
('241523551', 'luchitoLR'),
('479847640', 'OidArgentinos'),
('2198379294', 'NadQuetzo'),
('429991609', 'celodeteccion'),
('4428460367', 'smddhh'),
('3041730856', 'martin_zuin'),
('514907061', '_JuanFa'),
('1614045044', 'DelBottindari'),
('711952257756106752', 'tadeof98'),
('64873940', 'WandaMichelleM'),
('529106197', 'jaavi_ivaan'),
('536732192', 'MartinLCroci'),
('1270648255', 'CronicaDelNoa'),
('2201266541', 'Apuelgatolibera'),
('759391680', 'riosgabriela2'),
('872020333', 'EugeCasielles'),
('969187518', 'leticiamusciano'),
('1241432381984309252', 'LadyMatanza'),
('3991213937', 'EspecheVirginia'),
('1060183369105989634', 'VeroCarrizoPts'),
('1123393231', 'BetoJasdj'),
('852035474973614082', 'Vivian300991'),
('1196877068409151491', 'AndulceDaniel'),
('720024337508671488', 'adribuono1'),
('727933247053828096', 'melinoe123'),
('1261893858780217345', 'hipotenusaD'),
('42662751', 'marianoiannuzzi'),
('140266958', 'pablocarba'),
('51846587', 'claudiocagliani'),
('275195437', 'nikybrooks'),
('819795848', 'verogpaz'),
('386629677', 'saantipf'),
('776119831796051968', 'gabrielapiovan2'),
('1086411277553942528', 'urioseuskal'),
('159954654', 'jcva1'),
('1172202208756195328', 'Chrisbocon'),
('1266085019132493824', 'Rupelss2'),
('1310011866', 'FedeLynus'),
('3304221177', 'aalmada1982'),
('390442472', 'Micaa_Gonzalezz'),
('138116441', 'seba_chaca'),
('1147198529829556225', 'pdrntnldsm'),
('184570175', 'franaliotta'),
('272084806', 'EduardoBisognin'),
('4254041194', 'dbravo023'),
('1167759386', 'nachonal30'),
('1252845667375919104', 'rightstore_ar'),
('1730129822', 'LucaBonfante98'),
('231640467', 'julioclinares'),
('3388572610', 'Agustin_Sommer'),
('1015451932817838080', 'DonPepeArgento'),
('455088104', 'NicoBustAlamos'),
('1263219787137716228', 'keynesiadorni'),
('1469605838', 'RadioES1'),
('1220040001158774785', 'BanneadoK'),
('1875051822', 'WilliJimenz'),
('3130303259', 'AccidenteEterno'),
('1226791602', 'Antimateriak'),
('1221523598', 'LautiGarciaNiz'),
('1235997552455147520', 'FiscalRebelion'),
('174001423', 'chakiandrade'),
('1110190683791478784', 'tumbacarnero'),
('152371124', 'jcskillmann'),
('888256732446679040', 'Frabrisio999'),
('989225603961446402', 'Juampa_Bandoli'),
('963999227121717249', 'EquipodeFN2019'),
('180172189', 'matiasgazcon'),
('485302453', 'MartinCarp9'),
('1250415854790905864', 'FreedomWarro'),
('57038264', 'kineyDE'),
('878037921659576320', 'economictheoryy'),
('1263683107695230976', 'ReaccionL'),
('781662917829783552', 'rosi_sanjuan'),
('1399796946', 'Leo_Mollard'),
('3362605221', 'GeorchWn'),
('144154852', 'MerSalamone'),
('279673197', 'tinchoffs'),
('1045436037722501120', 'UCmisionesok'),
('1653907866', 'ludwigbor'),
('933028483', 'MartoEspinosa'),
('956621644243656705', 'ColuccioAgus'),
('160940716', 'MartinLoporassi'),
('177396973', 'Nati_Chavez'),
('1007664270', 'marianobusto'),
('161871030', 'Felii_N'),
('1266743715135197184', 'DecanoRubio'),
('77230392', 'DirectorCalero'),
('1271377274', 'AlaanDri'),
('1219305483862978560', 'Alepanett'),
('1273402817965932545', 'Despertar5D'),
('150256733', 'fedenamino'),
('1195763094', 'rightnowIQ'),
('1096718100', 'OlafGzWk'),
('2205869648', 'martin_brat'),
('765603396', 'CarlosAFerrer1'),
('632336389', 'AMA_SAR'),
('103664663', 'chris_lyt'),
('178083264', 'MLorenaSuarez'),
('1144677868045307907', '87Conservador'),
('1230482773405818882', 'lucilaroth83'),
('2350977349', 'MicaRagnarok'),
('283346566', 'JuliammD15'),
('224423660', 'meliromegialli'),
('1206608067321847808', 'luisinatuti'),
('121110471', 'Victor_Dls_'),
('134658859', 'JoseMolina4'),
('948600413657366528', 'JessyDaiii98'),
('1003612877436186624', 'BahiaPts'),
('1146276289579536385', 'TizianoR11'),
('1230367223614754816', 'adornicyberpunk'),
('253329327', 'pardocazador'),
('1227608440161341446', 'ElGatoDeTrump'),
('1269806547271585792', 'SMultifonico'),
('272027882', 'Dariososta'),
('1020518157210062848', 'maive_franco'),
('621611211', 'JuliScola'),
('755492140055224320', 'GisiiGonzalez18'),
('140258897', 'nicotestore'),
('27905268', 'Jek333'),
('1940771082', 'Fefe_Oficial_10'),
('305286270', 'IRVINHMartinez'),
('1247577692528087042', 'noedeurquiza'),
('285393495', 'ramirocabo1'),
('1022209388487106564', 'Agus_mendozaaa'),
('291876161', 'nandito72'),
('288508517', 'Scami1'),
('1131219679', 'JeronimoDeLuca3'),
('798878781821829120', 'AmandaRevista'),
('1238090185130344448', 'fuckingcrayc'),
('169490763', 'Andresnqn'),
('128294195', 'Darth_Tueritox'),
('130324372', 'Nosaqueo'),
('232099482', 'eugeecordoba'),
('2984924024', 'Derecha100pre'),
('54800194', 'santanajars'),
('586879498', 'C_Vallejos94'),
('70866400', 'ishaisoriano'),
('757936334', 'JulianBanuls'),
('1086709821829722113', 'DonVicenteV'),
('176467177', 'Yamivegatkd'),
('2788333591', 'nico_dubs98'),
('148342654', 'Purplemarian'),
('552434250', 'CandidaMar'),
('1418272213', 'marina_alr'),
('3299751693', 'banderas935'),
('1096999060505014273', 'boggiemanliber1'),
('614448405', 'lorenzo_martnez'),
('43692306', 'arquetipoC'),
('195506049', 'donaldtrompada1'),
('937511340', 'DONJULIO400'),
('1227437926138744833', 'carpoolliberta1'),
('2524296581', 'kapaxkapax'),
('1067360484', 'apellegrini2000'),
('316598043', 'DaniiSimonian'),
('746900304055119872', 'mariolita2005'),
('164320186', 'BastianNah'),
('4862707138', 'Gonzalo_Takuara'),
('822624489737428994', 'raulmuozmeza1'),
('83797102', 'GRILLOXXX'),
('1072499624', 'GastonGonda'),
('2466748116', 'EmiKalujerovich'),
('926514215904522240', 'FeFeLip1'),
('2802022850', 'LauGEspeche'),
('856794090083581952', 'Castaway_77'),
('592021363', 'MartinPrado_73'),
('190470475', 'morochodelplata'),
('761763242708459520', 'ByTyger27'),
('1059670008605929473', 'felisancho9'),
('1245786442598699010', 'baristassbx'),
('821595702824411136', 'brendapv_'),
('1081041200671543296', 'aldana_gisel'),
('171098877', 'noe_vr83'),
('778746536666632192', 'maxigomezO7'),
('900899136609943552', 'SobremesaM'),
('1139185084790136834', 'AlanPaulCasas1'),
('1145446341293826049', 'SePlantan'),
('1265766916783853569', 'JavierSalasGuns'),
('1241826553786490881', 'martindurand77'),
('1262148854499225600', 'Trumpista7'),
('4251597346', 'CrisDallOrso'),
('1892143602', 'nicolas_shady45'),
('902735746502668289', 'Silviairis56'),
('1248582669342052354', 'YellowW46425090'),
('3187667716', 'mateoduque201'),
('331095968', 'lauchamiranda'),
('179839590', 'chechoxeneize'),
('772090438970929152', 'nanystark'),
('1183583176796659712', 'osogordocatama1'),
('261034969', 'StephanieZarza'),
('1885201746', 'CordobaHernannn'),
('2845611337', 'gnsf35'),
('211133395', 'ddowidd'),
('1544001948', 'JuanLVeliz'),
('1112427124726607872', 'LiveFree2019'),
('1050523983840534529', 'liberalote12'),
('1086666890972409856', 'liberdiario'),
('1270716392522649600', 'ATransespecie'),
('37088458', 'Lemaverick'),
('438743116', 'jpvalentini'),
('740187739975454721', 'FpvPinamar'),
('1251549488797437953', 'Reaganicese'),
('1004000965010313216', 'VaneCaruso2019'),
('137118118', 'mbaptista13'),
('758687967594643456', 'Nicc_nic2'),
('846204927097614336', 'RominaAlba7'),
('128965386', 'Danymundoreves'),
('1120703311185838081', 'ArganarazNoel'),
('165994231', 'Wambita_Mdz'),
('33658481', 'jumedbec'),
('1246473994079010817', 'KittyAwake'),
('196619297', 'Maikherr'),
('763099079379390464', 'mueladejuicio1'),
('972924525368180737', 'brroken99'),
('197624925', 'diegoaldro'),
('2902546006', 'sinedhal'),
('863061965970821122', 'belcantare'),
('982379293459312640', 'celvazquez1'),
('32939093', 'fuhrn'),
('948439826', 'aeme_me'),
('1137068994341609473', 'monotrINDEC'),
('211889816', 'molinafito'),
('840912217113518080', 'menger_arg'),
('972837501093203968', 'Osvaldo63323395'),
('1262933082128121857', 'Nico88380230'),
('1100004269065994241', 'Antonio21229549'),
('1153477850965696514', 'Pablo30421051'),
('1245477500035219458', 'CivitasRevista'),
('1274791477839831040', 'mileiacostado'),
('895902428', 'Marii_Gorini'),
('1186924480771317761', '_AulAnCap_'),
('1268688085279260674', 'tobillosdepapel'),
('160200936', 'g_uribe'),
('4745512372', 'CarrLlorente'),
('1196190474752516096', 'LALove29684903'),
('1146960426804174848', 'AgujaPelle'),
('2575925202', 'ActuallyImPablo'),
('1147597713061621765', 'Fernandkombucha'),
('1216526579536363521', 'ViviValores'),
('756310790098022401', 'KevRamirez1096'),
('826833552864067584', 'Nacho_gorriti_'),
('2595864482', '0argaj'),
('1290176389', 'pastafrolaFeroz'),
('4805379683', 'FloridaMorocha'),
('130699218', 'elgorigeller'),
('262922650', 'agustin_skraba'),
('889891083563544576', 'Lau_Torrente'),
('1017492963121909760', 'UCParana'),
('1116264683072307200', 'macarenab___'),
('205025602', 'alejandro5461'),
('1228329889138388993', 'Alfred_LUD115'),
('307438940', 'LiliinesInes'),
('1138279786177093632', 'CharlyFerraris'),
('946940298', 'EAleph'),
('886314597346660352', 'Serj_Varela'),
('1257175625812652033', 'siemprebirra'),
('495156040', 'negro_standup'),
('894578004', 'MartinSup2012'),
('1082703470208131073', 'lospendejosderd'),
('1536940632', 'ANGELVANGOT'),
('175755071', 'clauditaprofe'),
('278407962', 'jearba7'),
('820331305187610624', '_constanzah'),
('907578528320933898', 'caycho_vivanc'),
('1086730241895215105', 'BeatrizBoglione'),
('1178895272673468416', 'Alayolaa'),
('487970821', 'queselevase'),
('235787220', 'mihebi'),
('549985200', 'WickedMachirulo'),
('1234978785361039360', 'JuanProcer'),
('1217109867577692175', 'OpinionLibreBo'),
('1250452423304523782', 'Hijodeluna3'),
('3959661621', 'marietayo19'),
('1247560634805489667', 'La_Conti_Lucha'),
('1124398687193567242', 'AlbertoMilei'),
('1074186956', 'Renacer_Humano'),
('1215714341850316801', '1manchesteriano'),
('1268538439915524098', 'ClaudiaOviedoOk'),
('51880565', 'FrannCurutchet'),
('351785013', 'noleftdude'),
('53463191', 'MartinoRoso'),
('1091146114647183360', 'riveroslu_'),
('2786179494', 'facucoudannes'),
('1260428310355611648', 'outofmilei'),
('170153437', 'albertfiochetti'),
('64802763', 'mcalcina777'),
('1144232797', 'zefe997ar'),
('268963243', 'marcohene'),
('954040950631882753', 'aguspeterson1'),
('163288550', 'joacoman21'),
('219291607', 'fdbiondi'),
('1209953428870488065', 'JotaEleEle2'),
('194265167', 'agustinbell354'),
('2614864089', 'Leandrorgodoy'),
('827936431679107073', 'ContraReloj_AM'),
('1621029272', 'David_Conejos'),
('1732475510', 'DollarbillArgy'),
('2392986650', 'LeaGabVil'),
('4042098112', 'LuzHohenhaim'),
('562544633', 'VladimirAAraque'),
('1128410431947718656', 'insider_longT'),
('1241859617468092428', 'InteresanteChe'),
('1245115687523270656', 'valutoledo_'),
('50646218', 'TottiAldo'),
('1243664952512131072', 'Andres_314164'),
('148013026', 'josesanchezACEP'),
('4637798717', 'majitogl37'),
('979363215938392069', 'agustin_pistone'),
('2748650549', 'martingnob'),
('964309192436801536', 'DaniPlanesS'),
('1026231301760851969', 'LeonnnnLeo'),
('1547719776', 'EstebanMisfeldt'),
('1273691570340941824', 'draculadorni'),
('189304665', 'littlekbz'),
('61529952', 'zanttyx'),
('3407905919', 'martinaawalk'),
('1220376205788053506', 'yaneeeeeeet'),
('397201210', 'reyman77'),
('788019381037072384', 'MiglioVerdeRiv'),
('2490627418', 'julian_darach'),
('3376352212', 'psicoticasedada'),
('1053855027008335872', 'Johnwick350'),
('1228816525', 'Backup_83'),
('210526092', 'antonycuenca'),
('67317086', 'ALe0n'),
('1120484014421417985', 'TejedaJoaco'),
('72269038', 'FedeCicerchia'),
('3996404895', 'KrutoySofia'),
('1215679245923602433', 'Cavalloso'),
('260294857', 'kevinf3006'),
('1067807021003612162', 'facundoumartinz'),
('1260251212525580293', 'meteoro201'),
('957354831705976833', 'Veglio68'),
('1267297222590377985', 'lionelmessidorn'),
('1274419351559516173', 'Uni2Moron'),
('3426867773', 'SolchoFerrari'),
('1015728670135209984', 'DeborahHuczek'),
('1229585931964948481', 'infinityadorni'),
('777019603', 'Agusdem2'),
('1117066786833408001', 'Jack19658574'),
('991823772910055424', 'STVelez7'),
('1252817374924828672', 'S74rd3m0n'),
('140161662', 'alvymaster'),
('248608006', 'jonathan_damian'),
('936730416618377216', 'Fiscalidad1'),
('1024775032705363970', 'LeticiaPavam'),
('700035738', 'Pantrox25'),
('1095732318025760768', 'facufr17'),
('1147370422230507521', 'Vazquez93S'),
('1243250705558835204', 'fuerza_liberal2'),
('164731354', 'leocartrainer'),
('546717698', 'pericoperez123'),
('1190749254618406912', 'LangdonTomas'),
('1588820971', 'richardmoroni'),
('879500860686049282', 'nerinanerinaa'),
('1252615337599741953', 'ulisesgon_'),
('1268960608101285889', 'neoliberadorni'),
('311550426', 'JimeGon_ortiz'),
('76125172', 'DiegoDiazNet'),
('974486197182623744', 'MauroPoletti9'),
('1206950522802053125', 'ZurdoEmpobrece2'),
('2189133223', 'PichonAkd'),
('368735096', 'elgaita66'),
('806253044', 'roliortigoza'),
('1133357134631067648', 'MarioRojasLuna4'),
('1058779277838241793', 'AlexanderAnsat'),
('2657861293', 'LilianaOgCa'),
('1250846668192448512', 'FundacionJU'),
('285425581', 'HernanTambella'),
('3167602115', 'BonyLeo16'),
('4925822861', 'GradiloneLuis'),
('738608909842190336', 'c3sarmv'),
('1187918992566042625', 'BordoValentin'),
('591933217', 'Jebus_M'),
('1266119344356016131', 'RickSanchezokk'),
('341864912', 'memoriadesiglos'),
('790468164224155648', 'MrBlueSky_22'),
('900254622', 'Pichaichi'),
('259331756', 'secretmont'),
('73720139', 'KeylorGranadosh'),
('1197226304191553537', 'MondelezMujeres'),
('1217947819845263362', 'uni2quilmes'),
('1265752998', 'Marianopatra'),
('19337342', 'gmalvicino'),
('2864013498', 'StoPatos'),
('3386372278', 'Palladius7'),
('52904099', 'netosport16'),
('855668113', 'borobioc'),
('1251589027', 'MauroFiasche'),
('831897223877238784', 'kurotesuta'),
('1231403387335401472', 'ColoTra1ner'),
('1515310268', 'GuestHugo'),
('771065389518381057', 'Juraija_M92'),
('129374767', 'carlos_sf'),
('185618685', 'PLO074'),
('2259811478', 'joaconaza13'),
('315314835', 'javiervg97'),
('3208152893', 'BrnichEsteban'),
('722621418366771201', 'FrannSuarez27'),
('973763155028561920', 'ger_castelli'),
('1222335451194888192', 'quispiero'),
('1249007241220538368', 'pl_jujuy'),
('112545867', 'AlessiaBSAS'),
('1189335121419218945', 'Reti_2000'),
('871434949517291520', 'MaiteVictoria02'),
('938101287505268737', 'de_mokita'),
('997320026230329344', 'lucasmorana'),
('1012278564580937728', 'Lorem66556248'),
('1175496314546786306', 'hastalalibertad'),
('1193550137123049475', 'UCeDeLib'),
('1264260015722049545', 'Julianratto7'),
('1267823318842748929', 'TheLiberalAle'),
('4180439621', 'elbunkerOK'),
('1134062706', 'CRodriguez_web'),
('1269452022094462977', 'LibertarioCL_'),
('201755000', 'EdgardoAnsede'),
('2368291681', 'iancho42'),
('1077796698989215744', 'GiuliaPiglioni2'),
('185493552', 'p4nc0'),
('312647083', 'LeonardoSaifert'),
('4726157721', 'mmilena64'),
('1253518986295291907', 'FarisanoCiro'),
('1033887169423790081', 'Josefinapeerez2'),
('1226644778282102785', 'PoliticoResumen'),
('1228383553743966208', 'EugeTinto'),
('2693083163', 'ciro_bustos'),
('884339270', 'Xe014'),
('1176870912471240705', 'Kevinnavarro991'),
('727043376', 'Juanma_1_1'),
('1244616210676940804', 'JuventudPLBsAs'),
('161435509', 'orguelito'),
('1072285208140021760', 'LautiSanchez25'),
('1115339501436534784', 'PuntoDeImpacto'),
('1243558038465916930', 'PL_Chaco'),
('474929746', 'marinat67'),
('1199848769325547522', 'Francis82135996'),
('122105757', 'angiebechem'),
('1213523145312751616', 'JuntosCampo'),
('796359474', 'maito240'),
('813514758573948928', 'WildWildLife2'),
('1241458315743449088', '_AyeCordoba'),
('1276659268377350145', 'IsabelA57127385'),
('2239023329', 'usuario787'),
('2780621945', 'juanjare2399'),
('521892972', 'JuanGayoso28'),
('585191897', 'skyrunner75'),
('760546253231054848', 'chinason14'),
('944315644639694848', 'OscarOgf2013'),
('275983043', 'JAVIERRACING01'),
('837711239094599683', 'lilblackcanary'),
('1087047019577991169', 'TomiFigueroa13'),
('1108604562020151296', 'elDurazno4'),
('123647102', 'orsarabormida'),
('4602341123', 'JAVC04'),
('1266524440797622273', 'MaruMarisa2'),
('1401890876', 'javierEzeRhoads'),
('2305744308', 'ProfeDeCine'),
('4284308894', 'eu68gib1'),
('928378650545807360', 'danivalentecba'),
('1241753004933603332', 'MariannBarbero'),
('1279146138726215680', 'elpadredelapija'),
('148427389', 'FranSoffia'),
('1252000419494191104', 'JosFernndezEP1'),
('886965292739555328', 'crisqoficial'),
('304517289', 'LascanoFlor'),
('597565799', 'lucianoh88'),
('828808193291780096', 'RiebDaniel'),
('1226385103552643072', 'BloffoR'),
('2758777287', 'villoldom'),
('1123442947171803141', 'mmatidelga2'),
('896457317562159104', 'MayraeQuiroz'),
('200003187', 'miraedgardo'),
('868148084370534404', 'guilledaniels'),
('1245733918831247360', 'Arg3727'),
('1303695440', 'hectorcontiok'),
('145744120', 'claudiamargari'),
('982272296214654977', 'calvoiglesias1'),
('1280769943', '_otroperez'),
('146309816', 'coffinbank6'),
('715946364706885632', 'pwerner20'),
('174042642', 'klimgon'),
('259855678', 'jccdeco'),
('3418314033', 'JoaquinOzorio11'),
('1246022047693787136', 'pts_fit_quilmes'),
('293275738', 'TheDanySide'),
('1191691833216307201', 'kiterider55'),
('1265437987694948352', 'atiendozurdos23'),
('886472892694790144', 'viconieva'),
('1245473802907193349', 'NuttingPablo'),
('4900219853', 'vegetadolarizad'),
('865221390', 'mingus1970'),
('1069287658852093952', 'Rosa07413751'),
('1188486434971365376', 'Limo28154151'),
('123085660', 'OctavioArg'),
('2835196253', 'leaubillo'),
('4890477861', 'PTS_V_Lopez'),
('1022813064', 'GuidiSilber'),
('1250491936315715588', 'autoconvocdeuda'),
('1276643782612660224', 'VignaliLorena'),
('137436143', 'JorgeBarreiros'),
('881323757620670466', 'JexuMV'),
('885316219708080129', 'quike_ck'),
('1241905285922533376', 'e_comision'),
('573859112', 'Eloy_S_Sanchez'),
('1147856280758996993', 'CiudadSuarez'),
('2969116757', 'SenlleJulian'),
('4025407659', 'diaz11_roland'),
('1244779293315604481', 'PLGualeguay'),
('235773153', 'TheMypsalito'),
('759478150254432257', 'maledns'),
('1121917522465447937', 'DemariaFabri'),
('1165408857876762626', 'PaulaSchaller'),
('1212248794777042944', 'GustavoMussin'),
('897485620850962432', 'AluAkb'),
('850764290185469952', 'ValenRR04'),
('2335479326', 'RamiLasala'),
('730380398048456704', 'griman_pedro'),
('762117471331557376', 'franokio'),
('1166088120061894658', 'AdrianaPiginiok'),
('1357989451', 'MelroseAle'),
('716462435914420224', 'bob3lipu'),
('1083789666581733378', 'Luchooporto1'),
('1278532765932236800', 'AbdonOut'),
('2252267237', 'anti_mandiok'),
('1211998674349199362', 'Magafaria80'),
('3675084736', 'unflacorandom'),
('872945720122363904', 'miguelRR021'),
('1705747142', 'AymMaxi'),
('783057917922664452', 'vicenolocco'),
('1001242472738156547', 'Anaporlasdudas'),
('232069780', 'inesangeleri'),
('843237517457588224', 'misbroncas'),
('3374825253', 'LiberalyPopular'),
('906916069000007680', 'Aguaslibertas'),
('1107679857109020672', 'ariza_will'),
('1186254453109866496', 'Inklings19'),
('1226549969047388167', 'chaja_chaja'),
('2459762880', 'IgnacioBTato'),
('737165558278291456', 'facudelirante'),
('967190000', 'JoseBogado6'),
('1044385866788024320', 'nicobartu'),
('1010607773267255301', 'JuanCar07401248'),
('380539881', 'Simon_Guitarra'),
('701359621357838336', 'franquitopala'),
('897616390114463744', 'DrDiegoRiveraP'),
('916634352', 'CelinaSparacino'),
('4182062601', 'gustavocanullo'),
('1265085276055093248', 'SentidoComunRT'),
('1175228815951441920', 'JustinianoSegu1'),
('1245912902353195009', 'la_efervescente'),
('1394508415', 'JPBonifazzi'),
('3177707595', 'spotornoangel'),
('3309610215', 'karitadegirasol'),
('1090243636288212994', 'xgr47'),
('1123746990653886464', 'trinchera_en'),
('1424478019', 'zequielfranco'),
('2302244912', 'pspastrana90'),
('311581423', 'franramos013'),
('94283303', 'guevarap'),
('1212534507464613888', 'Sword58895874'),
('2727004592', 'juangaunatorres'),
('862327982', 'EdwingTrejo'),
('1051597494944223233', 'dancab211'),
('1076521659220328449', 'AdrianSamudio2'),
('262243105', 'josevillenapetr'),
('1191424145269149696', 'Nicole09099'),
('1209964068196495362', 'mnkHLVS'),
('935216147129126917', 'cholo_1987'),
('967587399034396674', 'ANIMATEOK'),
('1127332005958574081', 'CandeGu_17'),
('1247921124056465408', 'ZonaZeroZero'),
('187056963', 'eleduss'),
('2442806298', 'GastonBres95'),
('1120176890021654528', 'DonRamonCbes'),
('2527049471', 'sandy1_s'),
('4145354296', '1nicoferrer'),
('1267661496731029505', 'Richardreiii901'),
('1268043728507330561', 'unArgquetrabaja'),
('2355621871', 'Hisu92'),
('247918188', 'Flavitoc'),
('475495743', 'ang_alfonso'),
('98170001', 'gobideladrones'),
('1112761292840992768', 'meidei__'),
('1256372529427623938', 'NoticiasNDM'),
('126770580', 'ojo_deaguila'),
('373983546', 'JamesRam0s'),
('1247745847405580288', 'afterburner_70'),
('161301246', 'blittzns'),
('191600854', 'NatuCarre'),
('745690301839310848', 'INDETRA_'),
('787995180234342400', 'marcosaltieri7'),
('203702396', 'martinalegro'),
('4107020003', 'MartinAncap'),
('848208542', 'jstwit17'),
('201685691', 'luiz_34_'),
('846356387194163202', 'NotoriusBLG'),
('1261402646201733120', 'MatiasB1776'),
('1268009328948195330', 'gocha2020'),
('238812063', 'chuymtzmty'),
('3357565607', 'sofchopi'),
('1205520283655974912', 'nicopauer'),
('110577081', 'adiazay'),
('1220315703275872257', 'ElPerroVigia'),
('1270433738032365569', 'DanielSiccardi'),
('104406171', 'Kinesiaaa'),
('1267137203135754241', 'Matte_BB'),
('153298327', 'difohak'),
('172866484', 'cesarakd2'),
('3337976633', 'Chinavercellino'),
('70664711', 'marcodecunha'),
('85986619', 'fefevar'),
('1092084866622078977', 'Lucas_Toledo_ok'),
('2582913242', 'rosenthal_maxi'),
('2756217394', 'andresglobe0'),
('1162442339702452226', 'Liberalosky'),
('1274617119901089792', '1banana1peso'),
('536448166', 'Negroland'),
('1231337613774270466', 'Darkorni'),
('1263193240725065728', 'CeDeUNacional'),
('143532884', 'cuchu89'),
('830211520525135874', 'AgustinF6299'),
('1100707620447571968', 'AnticoLeonel'),
('331923140', 'blackowl2'),
('1247428287497940992', 'AlvaroCastroLib'),
('1256711777552863239', 'Alberdi_Oficial'),
('207755511', 'Molymonth'),
('1166129394785689604', 'TranqueraD'),
('1217950469571719170', 'gabriel_gc1'),
('1245565874343469056', 'YogaGirlRo1'),
('1261706552412700672', 'Tomson_gz'),
('1220224992635510784', '1N_ciudadano'),
('3429195934', 'myone2_42'),
('739711844', 'plexposito'),
('903358081605742592', 'LightYagamiand'),
('1247883764031606787', 'CArgentea'),
('200898690', 'maxim_mj23'),
('1177508044365680642', '2011Rip'),
('196448958', 'GabrielScorolli'),
('807260988676435969', 'nanohlv'),
('1040858370675236864', 'ramirisho'),
('146884423', 'wilfredoportela'),
('3151564761', 'martinlsuarez'),
('352649963', 'GastonMollea'),
('4488332369', 'rociochumbitahb'),
('565495940', 'MLjubich'),
('973388367684685824', 'CarlosLozadaCa1'),
('984058797927878657', 'StutmanGraciela'),
('1066761444690206731', 'FrancoCarrizoPM'),
('747536293270290432', 'chakinau1'),
('947681356854808577', 'PepeArgento69'),
('981966976728870912', '111000111Arg'),
('406919768', 'NicolasGiuria'),
('490024848', 'ehktor33'),
('868215341217873922', 'LucassRosenthal'),
('138317316', 'federicofer85'),
('999662678019887105', 'leavila1987'),
('1254457599317213188', 'DrPhil50270308'),
('1268038432258953217', 'jopepupicoper'),
('752139479733964801', 'Shadow_Makoto'),
('846200848774565888', 'Profewolf2'),
('864194386573373441', 'MistSup'),
('881696560375005184', 'EzeFernandezPTS'),
('1102909588867899394', 'Adri24657275'),
('1201958731430481920', 'detectordebolu1'),
('1271918858358738945', 'doladorni'),
('179190242', 'estebanb86'),
('2511406453', 'ggfoxxx'),
('1162159362384834560', 'oso_abuelo'),
('1256307247308853254', 'HombreeeX'),
('201374873', 'Wnrusito'),
('2358056564', 'jhonnyblades'),
('2999965860', 'Nicassius22'),
('1241229614158094337', 'EGaruzzo'),
('1249794538996215810', 'DContinentes'),
('4121777230', 'MrFreeze_001'),
('516448223', 'GraneroSilvia'),
('717864145077592065', 'Ricardo15913'),
('797517211313303552', 'AleAtet'),
('1166485995241529346', 'Nic0_Cast1'),
('1215011932597563398', 'Le_Chalo'),
('186922016', 'MachoLibertario'),
('2667060612', 'Yoguibear4'),
('3399351683', 'dahcarp'),
('735505249738366976', 'locrofavaloro1'),
('1072675115249344514', 'pubertario_exe'),
('1275983410952101889', 'Miguelangelml20'),
('1670628144', 'Pablo22067371'),
('1246016495748030464', 'Roman_vallejoss'),
('1256994183828602880', 'Nikita204391763'),
('2827191071', 'sebadquiles'),
('2918627231', 'MaruVanGogh'),
('834206356076916738', 'Fedekr_ok'),
('974871824793251840', 'Lil_David_URU'),
('1001999972244574209', 'Julialderete98'),
('1133779830149976065', 'Bullish64035852'),
('1240805699652857856', 'Florenciamvarg1'),
('1255104633942487043', 'Aguscai09'),
('219865172', 'martinbruzzi'),
('821480809127362561', 'LeocVar'),
('934980577446584321', 'GuadagnoFacundo'),
('1071424137808277504', 'WyattEa33105679'),
('1137116263526912000', 'CtVincenzo'),
('1234567852117708801', 'JuvLibertJunin'),
('1236733643772608512', 'MarioQuinzano'),
('1250938975386251265', 'AmericaAbalos1'),
('1261535685476937729', 'mochirulo'),
('1262066370742714368', 'NicoCrespi2'),
('1267337842440704000', 'el_germicolor'),
('170303426', 'fran7gpj'),
('4406118376', 'DanielJrz6289'),
('746533939939016704', 'pablo_jg13'),
('952767416', 'Abel_almagro'),
('1226798199177957376', 'emleonardelli1'),
('1243410358070439937', 'santi_wolf0'),
('1279546616970698752', 'Cristin96056904'),
('953742418104475648', 'ArtilugiaObjeto'),
('996589494982856704', 'Gladys84052576'),
('1208231555174404096', 'j_m993'),
('1250284925615353858', 'queseyo42'),
('1273155144063102979', 'EternoMetal'),
('1273840946959040512', 'Cameron8111'),
('121368525', 'KenParkQ'),
('1229197252041658368', 'babelito3'),
('2943736679', 'elruloardel'),
('869990444184338433', 'CyberLibertario'),
('1077904451409711104', 'Nicoencpy'),
('1225551759302680577', '_____Matias____'),
('1237882818195271681', 'Esk1399'),
('2685524402', 's_ceja'),
('3055668207', 'LuisSalleres'),
('980781888360079360', 'pakhokpai'),
('1185731448034201601', 'lisandro_ms'),
('1227069733708730370', 'SamuB4iotti'),
('1257838966658805773', 'adorniconGorra'),
('1271273726324154369', 'JuliaRa18555473'),
('192747089', 'Arekushu20'),
('387230267', 'ElquisquiOK'),
('740348853568802816', 'luca_luzzi'),
('1176896600288956417', 'agustin_veuthey'),
('1259249220311277573', 'MrParrrley'),
('2624061472', 'iuspovi'),
('3335847610', 'hernanp76'),
('910466102517469184', 'Anto_Yanez_Rgz'),
('1267488712973221893', '4L3XL00P'),
('443560184', 'ElGre21'),
('875854338710753280', 'Santos_Torito'),
('93433195', 'ddremm'),
('1030203524926373888', 'sinapsisimpune'),
('1194087632541769729', 'Javier95955923'),
('1248440522840121349', 'Fmalfi1'),
('282869465', 'jcguerreroar'),
('3885622282', 'EnferxHerrera'),
('1128707932110168065', 'CJTheBlack_'),
('1158553078997639174', 'kuva_ibarra'),
('532693733', 'granchande'),
('1045501994042118144', 'CotyNosigliaOK'),
('1146530292095770624', '03Exee'),
('1254795647691210753', 'MakaroffAxel'),
('154615909', 'ingcm'),
('2642220443', 'gamerstdf'),
('488797510', '4lex_bater'),
('921411900', 'PabloIivoff'),
('1120519227713175556', 'livingmxsic'),
('1147242023784722435', 'Iv25722964'),
('1260414677156335617', 'Fernand14777561'),
('1263089798895542273', 'corro_rod'),
('2647804644', 'ramitademilan'),
('3025937662', 'RiveraTincho_'),
('815681514486763520', 'GonzaDeLaTorre'),
('1117571276539924481', 'LautySpeciale'),
('1192985176307064833', 'Genrannie1'),
('1237963366783737857', 'fernand10973514'),
('1458194768', 'FrankLasterLe'),
('208898566', 'anahicanton'),
('229159035', 'AlemanyNestor'),
('2652476050', 'karmacode696'),
('285808761', 'DiegoJave'),
('2912654607', 'estebanluna73'),
('600108516', 'ManuG100'),
('779039872791130112', 'FerZR_'),
('1248173367024406528', 'ElSegadorPai'),
('172194071', 'resinu'),
('2406689460', 'libertario_7'),
('295735522', 'JaraEsteban2'),
('880405519676170240', 'Mcdmerlo'),
('1209576466209476610', 'Gastonr13452038'),
('1240654007774990336', 'RonnieParaTodos'),
('1250621845851836421', 'Nic0Mar'),
('3397625158', 'AnchoDeEspalda'),
('4203572818', 'chinooaguerre'),
('4885049614', 'aguolmos90'),
('4887163726', 'monicaAmanno'),
('895397856097574913', 'romerosergioh'),
('1004140256436871168', 'ElVasco79'),
('1064954278454992896', 'AndyPalomo8'),
('1179118562788679680', 'SerpienteLiber1'),
('142487533', 'leopuente'),
('2329428972', 'OhigginsEnri'),
('2442424031', 'nico_pa88'),
('272820924', 'LLFaith'),
('819023325259329536', 'nicolas_friera'),
('1242841297590915072', 'NicoColucci2'),
('1272650276676255752', 'juventudalberd1'),
('923873526712586245', 'dxmixnxrce'),
('1197990152012017666', 'JeremiasUnder'),
('285741950', 'slrovere'),
('775177892670177280', 'fedeandrich'),
('1195736325586063360', '_RLuciano19__'),
('1206324214304825345', 'Francoarguellok'),
('1231701896253104129', 'ipacrippa'),
('263510978', 'juanjovacarezza'),
('2877303425', 'jpolivor'),
('1172829577061785600', 'Jose81788774'),
('1222412890419998721', 'Yamibernardeauu'),
('1246149858265833475', 'TituloPersonal1'),
('1266183233064108032', 'GorgonaaMedusa'),
('303557569', 'mmacciuci'),
('860197563848327170', 'BezardMariela'),
('983720604086960129', 'German13696958'),
('1082337423009501184', 'VulcanAvro'),
('1214410789009932288', 'MateoVillalba01'),
('1273121881114251264', 'liamname02'),
('182829704', 'yovi59'),
('914550618735378436', 'Gustavoantik'),
('1166349496231649287', 'pipitaconsult'),
('1254206888943792132', 'PabloHe37737552'),
('1269959643025092609', 'PilarUni2'),
('157430851', 'fgboschiazzo'),
('539743059', 'silviogazquez'),
('728392315488833536', 'AlioPablo'),
('736839974209851392', 'sergast77'),
('883493452507435008', 'BrunoJules21'),
('991124918371831808', 'WendigoPriest'),
('1071222262316064769', 'diegoexesan'),
('2693594605', 'MarianaSelzer'),
('396856013', 'DeivHernandez'),
('1077321928254341120', 'MrF4hrenhei7'),
('1095741400858140672', 'Ikalet1'),
('1242606853877628929', 'capitan_rich'),
('1564067683', 'agus84704'),
('590124122', 'lguerrerovcr'),
('894258046960115712', 'matemarchesi'),
('1012395653618642948', 'AzathothsHerald'),
('1125257431158857728', '100FranklinUSA'),
('1189830871903158272', 'AndresSleiman'),
('1240666225786716160', 'Chequeando3'),
('1253422142605029377', 'ErcoliLucio'),
('1278389112316268546', 'JakeRequiem'),
('704895578015141888', 'jorgesepuahu'),
('979095022455939072', 'Elba25644985'),
('1185756891919585280', 'PEDROJE22499468'),
('1245730372035514368', 'bunge_lucas'),
('1265056974619717632', 'viruschino8'),
('1001855085029330944', 'criscrespo11'),
('1186777801875251200', 'PabloSaravia82'),
('1243578228964548609', 'ImPhilpotts'),
('1254078869868630021', 'abigailvasconel'),
('4219600222', 'cristianocorral'),
('777573810300153857', 'Alanturing__'),
('797796173184729088', 'Bautibovalina'),
('1033107084206850049', 'eduardoaraoz5'),
('2569132780', '12c9add1bf8641f'),
('1178419891537432576', 'gapk_1961'),
('1190610728534913024', 'JuanPabloOlmed0'),
('1221859581682384896', 'Juliomarmercado'),
('1262247701527310337', 'LuisZapiola1'),
('1264742609748144129', 'idearg_'),
('1267297955687608320', 'Alan_cabj2020'),
('1273335640873107456', '39E679'),
('1944873960', 'Miau_Taffy'),
('228414452', 'ENilox'),
('2494402639', 'JuanMarcosAbaur'),
('602448639', 'nahuelon80'),
('915427189054693376', 'OttoJHannover'),
('1261821459460173824', 'coherenciabuen1'),
('1271127428103049217', 'MrBlueSky1610'),
('175260410', 'MaxMauro71'),
('2347667773', 'fabrimoralejo'),
('1182480295947321344', 'BurroneCarlos'),
('1727213438', 'damianw23'),
('1070741850758225921', 'Gonzalito1119'),
('1159996526388752384', 'Iroldan5'),
('1228071964948008961', 'Luci87540916'),
('1232679261112328192', 'LibertarioSla'),
('1233994688211890176', 'LibeLiberales'),
('1242887878268444672', 'Anglica00538962'),
('2176246537', 'DATOJURIDICO'),
('27171327', 'lady_xanax002'),
('4875884355', 'fabi_villacc'),
('493455834', 'elisabethalvar1'),
('931180475984605184', 'antiperoncho45'),
('1109912957545263105', 'ThurKann'),
('1167730328133349376', 'Axel80688533'),
('1214071907458240512', '_andressp_'),
('1221192346534064133', 'Spilucas12'),
('1245911859020083201', 'EstebanEdlM'),
('1248015669393850369', 'EstoicoVaron'),
('1258237977626542080', 'William06862881'),
('7642982', 'luuiis'),
('1045100383578796033', 't0masgomez'),
('1230306299625209857', 'AGastonari'),
('1253931101715922945', 'MileiZurdo'),
('1270878029204594689', 'Alberso6'),
('2214938617', 'peronedevidrio'),
('848523903295205376', 'ManuelitoAK47'),
('1099788188409909248', 'AnabelLilianaA2'),
('1206619893711429635', 'Silvest55719221'),
('1239346628395520000', 'JorgeRo64054602'),
('1259601776958980098', 'BeFrank01'),
('701105768037281792', 'gystavoescudero'),
('874591708000002049', 'Maximil52019923'),
('1049816959347544064', 'WainsteinMale'),
('1054162163911266304', 'JAltamirando'),
('1087963142829813762', 'Giova2894'),
('1179407500950593536', 'Pepe_Ruibarbo'),
('1259864589447110656', 'acido_ph1'),
('1268202485329559553', 'facuzuares'),
('2374083133', 'Leox121'),
('1125709781833060353', 'CegliaLiliana'),
('1220424908045459456', 'EditoraRuka'),
('1229479162357964808', 'eduvasco84'),
('1233544936269795334', 'MTSZ_12'),
('1251883175707541504', 'silveyraf'),
('1258854600389603329', 'Pointof10'),
('1266126369412562947', 'ca_maui'),
('126724966', 'yoelale'),
('1267342276684021762', 'Ogro68108586'),
('1269350791850196992', 'El_Hombre_Gris_'),
('573021023', 'cuquiquilmes'),
('909535417', 'HenryDiazCabeza'),
('1200449966285701120', 'saddemifranco'),
('1234387686460444672', 'Unsaloide'),
('1274361197266173952', 'RemandoEnArg'),
('204128401', 'gastik1'),
('234046127', 'xumarc'),
('3091761731', 'EstherNautaOK'),
('755043143687471105', 'tucan3951'),
('764151838543323136', 'gdaquinta'),
('1042761963439316992', 'SantiagoTassar1'),
('1266528580063895553', 'noticiashonest1'),
('1268049885607137281', 'GadsdenRule'),
('1269749144140369926', 'AcoriaLionel'),
('1271225108292677632', 'Swordandshiel10'),
('1277477162896015360', 'tomicolonna5'),
('299795130', 'Nicolas1605'),
('799774014663180288', 'Belciferas1'),
('1224108198237540353', 'ArgSinCordura'),
('1243600813500633089', 'elcondedraculap'),
('1246125683560103936', 'marianobr40'),
('1253458848238755848', 'Marian_Peverell'),
('1256285176839188482', 'NoeliaDenisse4'),
('1257126312571015173', 'xantra6'),
('1268699082127794182', 'angelkilla19'),
('1275424102229184512', 'Inge36101301'),
('1359300678', 'turkopato50'),
('354431090', 'francoantonioor'),
('800509353371414528', 'andresdcm1'),
('837167395886219265', 'Enrique93941653'),
('959657466714877953', 'ClontarinoPanda'),
('1193902596030967810', 'FerAgus3004'),
('1236477238842920960', 'AndreaS29303570'),
('1248458600663539713', 'NikoAyala10'),
('1250761311367106560', 'adictoamiverdad'),
('1262554322702868480', 'zonarepublicana'),
('1266170747132751878', 'Ema18Facu'),
('1266183184686997504', 'Solootracuenta5'),
('1274796273959305217', 'NealWarthon'),
('2924583230', 'DxL_SiuL'),
('984125460262121472', 'FedeArg_150'),
('1073336977381048320', 'Fernand42302669'),
('1121899050339577856', 'AMisenta'),
('1125864982514667524', 'clou1996'),
('1272603768790683649', 'davidro50025225'),
('702966726422609923', 'RechGamer'),
('1067449521679028225', 'El_Desconocido8'),
('1084850229717975042', 'miguel71414371'),
('1161102657521668097', 'FrankQueen12'),
('1170759638284984321', 'foxrtune'),
('1177594494939799553', 'Flor19705'),
('1249862620796108808', 'SepiaRen'),
('1264334134736048129', 'DSklofsky'),
('1264509539472355328', 'gashum73'),
('1273099574350090240', 'tumamaentang444'),
('1279544513091063814', 'liberal1385'),
('3991112963', 'RaulAArri'),
('1070491072873283584', '11Thiago_11'),
('1162606956403707905', 'Jorge_LdC__'),
('1214778923495690240', 'blasliberal1853'),
('1254058666585722880', 'balasanitarias'),
('1255549236323778569', 'AngryMexican2'),
('1271767191780818946', 'Chapu_rider'),
('2429200916', 'Alborotok'),
('3359449181', 'alearancibia94'),
('888566873658449920', 'diego60801532'),
('987717232343048193', 'GermenDario'),
('1156143540872843264', 'LuisRiq69793885'),
('1160745034800619522', 'equus34619245'),
('1161267596597108736', 'M2Megarexo'),
('1219812007819579393', 'J4V13RC4N70'),
('1243330918242226176', 'rmtrbl1'),
('1257784342119620610', 'MarielMMuozRom1'),
('1264620282725183491', 'LHBurgosF'),
('1265666404667330561', 'Info12288293'),
('1273717354036371456', 'Claudio25736753'),
('1275284297021259776', 'elgrangordotony'),
('1204514538713997312', 'HernanC01967642'),
('1237281471842394113', 'Paulamumush'),
('1244008879824003072', 'SmurfApex'),
('1246342320846442496', 'Ricardo07287273'),
('1262768465997414406', 'ClipsLiber'),
('1267544598471204865', 'NeriTorrez'),
('1267601567903027201', 'Cossasquepasann'),
('947361126014160896', 'Inserte_nombre_'),
('985975179024138240', 'HoyJj763911'),
('1241880914302402560', 'Fernand62446624'),
('1244673031454240771', 'Cesar51421214'),
('1278155702666756101', 'V24786402'),
('994772412150505472', 'EspSailor')
]

# %%
for i in range(len(tt)):
    print(i, 'of', len(tt))
    j = tt[i]
    try:
        scrap_save_user(j[1], j[0] , verbose=True)
    except:
        print('####### ERROR #######', j)
# Out:
# 0 of 2979
# ------Init: ChrisGiles_
# Not spanish ChrisGiles_
# 1 of 2979
# ------Init: JuanGrabois
# Saving JuanGrabois ...
# Saved JuanGrabois
# 2 of 2979
# ------Init: IglesiasDiego
# Saving IglesiasDiego ...
# Saved IglesiasDiego
# 3 of 2979
# ------Init: Facundo_Moyano
# Saving Facundo_Moyano ...
# Saved Facundo_Moyano
# 4 of 2979
# ------Init: mayrasmendoza
# Saving mayrasmendoza ...
# Saved mayrasmendoza
# 5 of 2979
# ------Init: NicoDujovne
# Saving NicoDujovne ...
# Saved NicoDujovne
# 6 of 2979
# ------Init: Winston_Dunhill
# Saving Winston_Dunhill ...
# Saved Winston_Dunhill
# 7 of 2979
# ------Init: dandrezner
# Not spanish dandrezner
# 8 of 2979
# ------Init: Martin_M_Guzman
# RESET_TOKENS
# Saving Martin_M_Guzman ...
# Saved Martin_M_Guzman
# 9 of 2979
# ------Init: anadoluagency
# Not spanish anadoluagency
# 10 of 2979
# ------Init: LPOArg
# Saving LPOArg ...
# ####### ERROR ####### ('108968018', 'LPOArg')
# 11 of 2979
# ------Init: javierpanza
# ...
